# %%
from scipy.linalg import svd
import numpy as np

# %%
rng = np.random.default_rng()
alfa = rng.random((100, 100))

# %%
alfa_svd = svd(alfa)

# %%
alfa[:, 0:3].transpose()
# Out:
# array([[0.35382797, 0.89340581, 0.15782387, 0.94343143, 0.17033842,
#         0.23875441, 0.82288755, 0.4187852 , 0.60221031, 0.08962646,
#         0.27561927, 0.23369792, 0.77845519, 0.3971182 , 0.33618571,
#         0.96942513, 0.26982705, 0.67313529, 0.76462093, 0.93535475,
#         0.28172418, 0.89256244, 0.81214617, 0.03421021, 0.36386634,
#         0.6043444 , 0.62711174, 0.43363654, 0.29017227, 0.08059895,
#         0.4018243 , 0.20871293, 0.44082873, 0.06006757, 0.65555382,
#         0.76337312, 0.95150412, 0.73098866, 0.63897012, 0.80118361,
#         0.06539457, 0.56428028, 0.92809939, 0.72135715, 0.84419857,
#         0.09175442, 0.06651793, 0.255911  , 0.65087881, 0.31936213,
#         0.12642186, 0.22124545, 0.04091791, 0.73544371, 0.83274778,
#         0.34956717, 0.02443249, 0.19119136, 0.92665604, 0.79553213,
#         0.56503155, 0.61545584, 0.84790977, 0.64625891, 0.98126749,
#         0.2796809 , 0.26293309, 0.86575111, 0.5359009 , 0.00544605,
# ...

# %%
alfa @ alfa.transpose()
# Out:
# array([[26.17517672, 21.86909325, 20.37130193, ..., 19.26596229,
#         19.6824083 , 22.04295808],
#        [21.86909325, 34.2407364 , 27.77989852, ..., 23.57974216,
#         22.68983003, 26.23312528],
#        [20.37130193, 27.77989852, 37.24294075, ..., 25.10580368,
#         24.70362197, 26.15874585],
#        ...,
#        [19.26596229, 23.57974216, 25.10580368, ..., 30.65928483,
#         21.36196499, 24.44874159],
#        [19.6824083 , 22.68983003, 24.70362197, ..., 21.36196499,
#         29.26456521, 24.72975617],
#        [22.04295808, 26.23312528, 26.15874585, ..., 24.44874159,
#         24.72975617, 34.24521007]])

# %%
np.savetxt("alfa.csv", alfa, delimiter=",")
