# %%
from itertools import permutations
from nltk.corpus import words
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8a4e45b0eca3> in <module>
#       1 from itertools import permutations
#       2 from nltk.corpus import words
# ----> 3 from functools import filter
#
# ImportError: cannot import name 'filter' from 'functools' (/Users/milessmith/miniconda3/lib/python3.8/functools.py)

# %%
remaining = "qwryuipdfghjkzxcvbm"

# %%
potential_words = ["".join(_) for _ in permutations(remaining, 5)]

# %%
words[0]
# Out:
# 'qwryu'

# %%
filtered_potentials = [
    word
    for word in potential_words
    if "r" in word
    and "i" in word
    and "m" in word
    and not word.startswith("q")
    and word[2] != "m"
    and word[3] != "i"
    and word[4] != "r"
]
# Out:
# ['wqrmi', 'wqirm', 'wrqmi', 'wrymi', 'wrumi', 'wriqm', 'wriym', 'wrium', 'wripm', 'wridm', 'wrifm', 'wrigm', 'wrihm', 'wrijm', 'wrikm', 'wrizm', 'wrixm', 'wricm', 'wrivm', 'wribm', 'wrimq', 'wrimy', 'wrimu', 'wrimp', 'wrimd', 'wrimf', 'wrimg', 'wrimh', 'wrimj', 'wrimk', 'wrimz', 'wrimx', 'wrimc', 'wrimv', 'wrimb', 'wrpmi', 'wrdmi', 'wrfmi', 'wrgmi', 'wrhmi', 'wrjmi', 'wrkmi', 'wrzmi', 'wrxmi', 'wrcmi', 'wrvmi', 'wrbmi', 'wyrmi', 'wyirm', 'wurmi', 'wuirm', 'wiqrm', 'wirqm', 'wirym', 'wirum', 'wirpm', 'wirdm', 'wirfm', 'wirgm', 'wirhm', 'wirjm', 'wirkm', 'wirzm', 'wirxm', 'wircm', 'wirvm', 'wirbm', 'wirmq', 'wirmy', 'wirmu', 'wirmp', 'wirmd', 'wirmf', 'wirmg', 'wirmh', 'wirmj', 'wirmk', 'wirmz', 'wirmx', 'wirmc', 'wirmv', 'wirmb', 'wiyrm', 'wiurm', 'wiprm', 'widrm', 'wifrm', 'wigrm', 'wihrm', 'wijrm', 'wikrm', 'wizrm', 'wixrm', 'wicrm', 'wivrm', 'wibrm', 'wprmi', 'wpirm', 'wdrmi', 'wdirm', 'wfrmi', 'wfirm', 'wgrmi', 'wgirm', 'whrmi', 'whirm', 'wjrmi', 'wjirm', 'wkrmi', 'wkirm', 'wzrmi'
# ...
