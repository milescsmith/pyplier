# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
def copyMat(df: pd.DataFrame, zero: bool = False) -> pd.DataFrame:
    if zero:
        dfnew = pd.DataFrame(
            np.zeros(shape=df.shape), index=df.index, columns=df.columns
        )
    else:
        dfnew = df.copy(deep=True)
    return dfnew

# %%
from typing import Dict, List, Tuple
import numpy as np
from scipy.stats import mannwhitneyu, norm


def AUC(labels: pd.Series, values: pd.Series) -> Dict[str, float]:
    posii = labels[labels > 0]
    negii = labels[labels <= 0]
    posn = len(posii)
    negn = len(negii)
    posval = values[posii.index]
    negval = values[negii.index]
    if posn > 0 and negn > 0:
        statistic, pvalue = mannwhitneyu(posval, negval, alternative="greater")
        conf_int_low, conf_int_high = mannwhitneyu_conf_int(posval, negval)
        res = {
            "low": conf_int_low,
            "high": conf_int_high,
            "auc": (statistic / (posn * negn)),
            "pval": pvalue,
        }
    else:
        res = {"auc": 0.5, "pval": np.nan}

    return res


def mannwhitneyu_conf_int(
    x: np.array, y: np.array, alpha: float = 0.05
) -> Tuple[float, float]:
    n = len(x)
    m = len(y)

    N = norm.var(1 - alpha / 2)

    diffs = sorted([i - j for i in x for j in y])

    # For an approximate 100(1-a)% confidence interval first calculate K:

    nm = n * m
    top = nm * (n + m + 1)
    right = N * np.sqrt(top / 12)
    left = (n * m) / 2
    K = left - right

    k = int(round(n * m / 2 - (N * (n * m * (n + m + 1) / 12) ** 0.5)))

    # The Kth smallest to the Kth largest of the n x m differences
    # lx and ly should be > ~20
    CI = (diffs[k], diffs[len(diffs) - k])
    return CI

# %%
x = posval
y = negval
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8143/3501235429.py in <module>
# ----> 1 x = posval
#       2 y = negval
#
# NameError: name 'posval' is not defined

# %%
negval

# %%
group1 = [38, 26, 29, 41, 36, 31, 32, 30, 35, 33]
group2 = [45, 28, 27, 38, 40, 42, 39, 39, 34, 45]

# %%
x = group1
y = group2

# %%
n = len(x)
m = len(y)

# %%
N = norm.ppf(1 - 0.05 / 2)

# %%
diffs = sorted([i - j for i in x for j in y])

# %%
nm = n * m
top = nm * (n + m + 1)
right = N * np.sqrt(top / 12)
left = (n * m) / 2
K = left - right

# %%
K
# Out:
# 24.072113591318864

# %%
(diffs[round(K)], diffs[len(diffs) - round(K)])
# Out:
# (-10, 1)

# %%
n = len(x)
m = len(y)

N = norm.var(1 - 0.05 / 2)

diffs = sorted([i - j for i in x for j in y])

# For an approximate 100(1-a)% confidence interval first calculate K:

k = int(round(n * m / 2 - (N * (n * m * (n + m + 1) / 12) ** 0.5)))

# %%
# The Kth smallest to the Kth largest of the n x m differences
# lx and ly should be > ~20
CI = (diffs[k], diffs[len(diffs) - k])

# %%
CI
# Out:
# (-8, -3)

# %%
dataPath = Path("/home/milo/workspace/pyplier/tests/data/crossVal")
data = pd.read_csv(filepath_or_buffer=dataPath.joinpath("data.csv"), index_col=0)

# %%
data
# Out:
#             BD8001    BD8002    BD8003    BD8004    BD8005    BD8006  \
# GAS6     -1.505242  0.188428  1.382268 -0.886040  0.218978 -1.659888
# MMP14    -1.362254  1.426659 -0.112956 -0.547275 -0.657120  0.623815
# MARCKSL1 -1.559936  1.247540 -2.110556 -0.721440 -0.058441  0.154611
# SPARC     0.465116 -0.849214  0.790658  0.906851  0.163648  0.117905
# CTSD      0.024942  0.206589 -1.452483 -1.102910  0.034775 -0.016322
# ...            ...       ...       ...       ...       ...       ...
# TRPM4    -0.324201 -0.774261 -0.128307 -0.540268  1.317625  0.363039
# LAIR2    -0.394921  0.851458 -2.219011  1.623721 -2.460171 -0.319912
# ZNF135    0.545218 -0.707431  0.174777 -0.063097 -0.423388  0.432197
# MARCH3    1.117124 -0.882370  0.078125  0.027025 -0.312435 -0.634321
# SEPT8     0.476287  1.463197 -1.548634 -0.440095  0.353634  1.007847
#
#             BD8007    BD8008    BD8009    BD8010  ...    BD8031    BD8032  \
# GAS6      2.796534  0.829210 -1.649642 -0.699206  ...  0.167190 -0.443537
# MMP14     0.162686  0.399899 -0.959655  2.260257  ... -0.136098 -0.776283
# MARCKSL1  1.487958 -0.045567  1.409842  0.235813  ... -2.010731  1.165882
# SPARC    -1.060804 -1.701798  0.920468 -1.141010  ... -2.644481 -0.004298
# CTSD      0.844618  0.483747 -0.650142  1.753523  ... -0.776214  0.643598
# ...            ...       ...       ...       ...  ...       ...       ...
# TRPM4    -0.019754  1.232543 -1.814046  1.174763  ...  0.255074  0.288240
# LAIR2     0.197574  0.627586 -0.413208  0.143300  ... -1.237987 -0.185263
# ZNF135   -0.180568  0.141946 -0.231568  0.471386  ... -0.121949 -0.133662
# MARCH3   -0.208948 -0.704559  1.774945  1.256757  ... -0.669562  0.712260
# SEPT8    -0.433875  0.640883 -0.208530 -1.475209  ... -0.169933 -0.340282
#
#             BD8033    BD8034    BD8038    BD8041    BD8042    BD8043  \
# GAS6     -0.413695 -0.033962 -0.003753 -0.562015 -1.457108  0.254652
# MMP14     0.401661 -0.029038 -1.121673 -0.977343 -1.771282  0.948462
# MARCKSL1 -0.192181 -0.207469 -1.077898  0.035008 -0.486909 -0.433482
# SPARC     0.902712 -0.857343 -0.450150 -0.669798  0.684989 -0.941961
# CTSD     -0.739288 -0.768372 -1.777247  0.343815 -0.374175  0.949864
# ...            ...       ...       ...       ...       ...       ...
# TRPM4    -1.268223  0.669198  0.361300 -0.930080  0.117951 -0.105594
# LAIR2     0.607988  0.617346 -0.586569 -1.212232  0.003727  0.496207
# ZNF135   -0.745435  0.416144 -0.409687 -1.083912 -0.355580  0.583608
# MARCH3    0.291270  0.131922  0.131922 -1.069672  0.535645 -0.186776
# SEPT8     0.740365  1.105168  1.186127  1.140807  1.566995  0.038750
#
#             BD8044    BD8045
# GAS6     -0.945488  1.285548
# MMP14     0.723387  0.895571
# MARCKSL1  0.683989  2.203569
# SPARC    -0.446238  0.891104
# CTSD      0.449915  2.400907
# ...            ...       ...
# TRPM4    -0.502940  1.052108
# LAIR2    -0.900624  0.757522
# ZNF135    1.140988 -0.355580
# MARCH3   -2.450563  0.417511
# SEPT8    -0.060248 -0.774228
#
# [5964 rows x 36 columns]

# %%
plierRes_b = pd.read_csv(
    filepath_or_buffer=dataPath.joinpath("plierRes_b.csv"), index_col=0
)
plierRes_c = pd.read_csv(
    filepath_or_buffer=dataPath.joinpath("plierRes_c.csv"), index_col=0
)
plierRes_residual = pd.read_csv(
    filepath_or_buffer=dataPath.joinpath("plierRes_residual.csv"), index_col=0
)
plierRes_u = pd.read_csv(
    filepath_or_buffer=dataPath.joinpath("plierRes_u.csv"), index_col=0
)
plierRes_z = pd.read_csv(
    filepath_or_buffer=dataPath.joinpath("plierRes_z.csv"), index_col=0
)

# %%
heldoutgenes = pd.read_csv(filepath_or_buffer=dataPath.joinpath("heldOutGenes.csv"))

# %%
heldoutgenes
# Out:
#                            name   value
# 0     IRIS_Bcell-Memory_IgG_IgA  SPDYE1
# 1     IRIS_Bcell-Memory_IgG_IgA    HEY1
# 2     IRIS_Bcell-Memory_IgG_IgA   FCRL1
# 3     IRIS_Bcell-Memory_IgG_IgA    AFF3
# 4     IRIS_Bcell-Memory_IgG_IgA    COCH
# ...                         ...     ...
# 8004      PID_PI3KPLCTRKPATHWAY  PIK3R1
# 8005      PID_PI3KPLCTRKPATHWAY    GRB2
# 8006      PID_PI3KPLCTRKPATHWAY    SOS1
# 8007      PID_PI3KPLCTRKPATHWAY   FOXO3
# 8008      PID_PI3KPLCTRKPATHWAY  STAT5A
#
# [8009 rows x 2 columns]

# %%
heldOutGenes = {k: g["value"].tolist() for k, g in heldoutgenes.groupby("name")}

# %%
heldOutGenes
# Out:
# {'BIOCARTA_BCR_PATHWAY': ['MAPK14', 'CD79B', 'CALM2', 'PPP3CB', 'JUN', 'RAF1'],
#  'BIOCARTA_BIOPEPTIDES_PATHWAY': ['RAF1',
#   'MYLK',
#   'GNB1',
#   'MAPK3',
#   'CAMK2D',
#   'HRAS',
#   'PLCG1'],
#  'BIOCARTA_CARM_ER_PATHWAY': ['HDAC5',
#   'NCOR2',
#   'PHB2',
#   'CCND1',
#   'HDAC9',
#   'SRA1'],
#  'BIOCARTA_CHREBP2_PATHWAY': ['YWHAG',
#   'PPP2R2B',
#   'PPP2R5B',
#   'PPP2CA',
#   'PPP2R4',
#   'PPP2R5C'],
#  'BIOCARTA_DEATH_PATHWAY': ['CYCS', 'LMNA', 'BID', 'CHUK', 'CASP10', 'BIRC2'],
#  'BIOCARTA_EGF_PATHWAY': ['PRKCA', 'JUN', 'ELK1', 'RAF1', 'GRB2', 'RASA1'],
#  'BIOCARTA_FAS_PATHWAY': ['ARHGDIB', 'MAP3K1', 'CFLAR', 'DFFA', 'SPTAN1'],
#  'BIOCARTA_FCER1_PATHWAY': ['NFATC3',
#   'FCER1A',
#   'PPP3CB',
#   'MAPK3',
#   'NFATC2',
#   'MAPK1',
#   'PIK3R1'],
#  'BIOCARTA_FMLP_PATHWAY': ['NFATC3',
#   'RAC1',
#   'RAF1',
#   'CALM1',
#   'MAP2K1',
#   'MAPK3'],
#  'BIOCARTA_GPCR_PATHWAY': ['GNAS',
#   'PPP3CA',
#   'PLCG1',
#   'MAP2K1',
#   'PRKAR1B',
#   'GNAQ'],
#  'BIOCARTA_HIVNEF_PATHWAY': ['CFLAR',
#   'TRADD',
#   'PSEN1',
#   'CASP2',
#   'PSEN2',
#   'CHUK',
#   'TNF',
#   'CDK11A',
#   'BID',
#   'CASP8',
#   'FADD'],
#  'BIOCARTA_IL2RB_PATHWAY': ['SOCS1',
#   'FOS',
#   'GRB2',
#   'SOS1',
#   'RPS6KB1',
#   'MYC',
#   'FASLG'],
#  'BIOCARTA_INTEGRIN_PATHWAY': ['ACTN1',
#   'BCR',
#   'CSK',
#   'MAP2K2',
#   'MAPK8',
#   'MAP2K1'],
#  'BIOCARTA_KERATINOCYTE_PATHWAY': ['FAS',
#   'EGF',
#   'RAF1',
#   'PRKCQ',
#   'TNFRSF1A',
#   'MAP3K5',
#   'MAPK13',
#   'RELA'],
#  'BIOCARTA_MAPK_PATHWAY': ['MAP2K4',
#   'MKNK1',
#   'CREB1',
#   'MAP3K2',
#   'MKNK2',
#   'DAXX',
#   'MAPK14',
#   'TGFBR1',
#   'RELA',
#   'RAPGEF2',
#   'MAP3K12',
#   'RIPK1',
#   'MAP4K4',
#   'HRAS',
#   'MAP3K5',
#   'MAPK6'],
#  'BIOCARTA_MET_PATHWAY': ['CRK',
#   'PTK2',
#   'JUN',
#   'PIK3CA',
#   'DOCK1',
#   'GAB1',
#   'PAK1'],
#  'BIOCARTA_MPR_PATHWAY': ['PRKAR2A', 'ARPC1A', 'PRKAR1B', 'ARPC4', 'ACTR3'],
#  'BIOCARTA_NFAT_PATHWAY': ['PIK3R1',
#   'CALR',
#   'MAPK1',
#   'CAMK4',
#   'RPS6KB1',
#   'PPP3CC',
#   'HBEGF'],
#  'BIOCARTA_P38MAPK_PATHWAY': ['RPS6KA5',
#   'RIPK1',
#   'HSPB1',
#   'TRADD',
#   'MAPKAPK5',
#   'MEF2A',
#   'TRAF2'],
#  'BIOCARTA_PAR1_PATHWAY': ['PIK3R1',
#   'F2RL3',
#   'MAP3K7',
#   'ARHGEF1',
#   'ARHGEF3',
#   'PLCB1'],
#  'BIOCARTA_PDGF_PATHWAY': ['CSNK2A1', 'FOS', 'JUN', 'MAPK3', 'PLCG1', 'ELK1'],
#  'BIOCARTA_PPARA_PATHWAY': ['CPT1B',
#   'CREBBP',
#   'HSPA1A',
#   'RXRA',
#   'MAPK3',
#   'MAPK1',
#   'PIK3CA',
#   'RELA',
#   'CD36'],
#  'BIOCARTA_RHO_PATHWAY': ['ARHGAP6', 'LIMK1', 'TLN1', 'ACTR3', 'RHOA', 'MYLK'],
#  'BIOCARTA_TCR_PATHWAY': ['VAV1',
#   'PPP3CB',
#   'NFATC1',
#   'RAC1',
#   'LAT',
#   'LCK',
#   'MAP2K1',
#   'NFKB1'],
#  'BIOCARTA_TOLL_PATHWAY': ['CD14',
#   'TLR2',
#   'TLR7',
#   'MYD88',
#   'RELA',
#   'TLR6',
#   'TRAF6'],
#  'Custom_Treg': ['FLT3LG', 'TRAF1'],
#  'DMAP_BASO1': ['PTPRK', 'TNFRSF17'],
#  'DMAP_BCELLA1': ['KIAA0125',
#   'APBB2',
#   'MS4A1',
#   'ADAR',
#   'IRS1',
#   'PTPRK',
#   'RASGRP3',
#   'SYT17',
#   'RRAGC',
#   'HLA-DOB',
#   'ADARB1',
#   'HLA-C',
#   'TSPYL2'],
#  'DMAP_BCELLA2': ['BLNK',
#   'COL4A3',
#   'BLK',
#   'P2RX5',
#   'IGJ',
#   'PTPRK',
#   'KIAA0125',
#   'ABCB4',
#   'CR2',
#   'LARGE'],
#  'DMAP_BCELLA3': ['FCRL2',
#   'KIAA0125',
#   'RRAGC',
#   'NR3C2',
#   'EIF2AK3',
#   'COBLL1',
#   'TSPYL2',
#   'POU2AF1',
#   'ZDHHC14',
#   'CAMK2N1'],
#  'DMAP_BCELLA4': ['BLK',
#   'COBLL1',
#   'BANK1',
#   'PRDM4',
#   'COL4A4',
#   'FAM102A',
#   'COL4A3',
#   'RALGPS2',
#   'OSBPL10'],
#  'DMAP_DENDA1': ['TNFRSF21',
#   'TPM2',
#   'EPHA2',
#   'COBLL1',
#   'LGMN',
#   'AXL',
#   'TNFRSF17',
#   'AHI1',
#   'BLNK'],
#  'DMAP_DENDA2': ['MNDA',
#   'CDH1',
#   'CLEC4A',
#   'THBD',
#   'NDRG2',
#   'ALDH2',
#   'FCN1',
#   'CD1C'],
#  'DMAP_EOS2': ['SMPDL3A', 'TCL1A', 'MS4A3', 'PEG10'],
#  'DMAP_ERY1': ['PBX1',
#   'PPM1H',
#   'F2R',
#   'SLC39A8',
#   'POLE',
#   'MEIS1',
#   'CEP70',
#   'FAM117A'],
#  'DMAP_ERY2': ['EFHC2',
#   'F2R',
#   'MEST',
#   'DNM3',
#   'TSPO',
#   'SLPI',
#   'MPL',
#   'CENPE',
#   'POLE',
#   'PBX1',
#   'ANXA3'],
#  'DMAP_ERY3': ['GAPVD1',
#   'DNAJB4',
#   'RNF11',
#   'ITSN1',
#   'PCCB',
#   'HBD',
#   'PQLC1',
#   'DCXR',
#   'KCTD9',
#   'RANBP1',
#   'KRT1',
#   'SMOX',
#   'CLCN3',
#   'AP2S1',
#   'PSMF1',
#   'REXO2',
#   'C9orf40',
#   'DAD1',
#   'PPOX',
#   'ARF1',
#   'WBP2',
#   'PPME1',
#   'NEDD4',
#   'MPP1',
#   'BRD4',
#   'RBX1',
#   'CDKL1',
#   'MAP2K3',
#   'SERINC3',
#   'RMND5A',
#   'MBNL3',
#   'MAFG',
#   'SAMD9',
#   'RNF123',
#   'UBE2B',
#   'DCTN3',
#   'RAB11B',
#   'GTPBP1',
#   'PRR5',
#   'DNAJC6',
#   'CDIPT',
#   'ECT2',
#   'USP32',
#   'CARHSP1',
#   'RAP1GAP',
#   'PIGQ',
#   'GHITM',
#   'CARM1',
#   'HEXIM1',
#   'DCUN1D1',
#   'ARF4',
#   'MAP1LC3B',
#   'GCLM',
#   'MOSPD1',
#   'ANK1',
#   'CYB5R1',
#   'CLIC2',
#   'FECH',
#   'CREG1',
#   'ACP1',
#   'SORBS1',
#   'FKBP8',
#   'MFHAS1',
#   'RAP2A',
#   'GABARAPL1',
#   'SLC22A4',
#   'FAM20B',
#   'ELOVL6',
#   'ABCG2',
#   'HBQ1',
#   'RNF187',
#   'NAPA',
#   'UBB'],
#  'DMAP_ERY4': ['PDCD10',
#   'DNAJA2',
#   'SLC25A37',
#   'XPO7',
#   'OPA1',
#   'DYRK3',
#   'TUFT1',
#   'MBNL3',
#   'RNF123',
#   'UBAP1',
#   'BUB1',
#   'ZNF19',
#   'MFN2',
#   'MAFG',
#   'MBD5',
#   'PDZK1IP1',
#   'UBB',
#   'ZBTB17',
#   'CDH1',
#   'FKBP8',
#   'HDGF',
#   'E2F4',
#   'PTPRF',
#   'GAPVD1',
#   'HBQ1',
#   'HPS1',
#   'TRIM23',
#   'CUL4A',
#   'WNK1',
#   'CLPX',
#   'RPIA',
#   'GPX1',
#   'PIP5K1B',
#   'TGM2',
#   'TMOD1',
#   'SLC7A5',
#   'NFE2',
#   'TRIP12',
#   'BCL2L1',
#   'MYL4',
#   'SELENBP1',
#   'HBB',
#   'TERF2',
#   'NFIX',
#   'SHARPIN',
#   'WIPI2',
#   'DDB1',
#   'EIF2AK1',
#   'MICAL2',
#   'C9orf78',
#   'FBXO9',
#   'NAPA',
#   'SERPINI1',
#   'RAN',
#   'PPM1A',
#   'GABARAPL1',
#   'REXO2',
#   'DHX29',
#   'GHITM',
#   'CMAS',
#   'UBL5',
#   'FZR1'],
#  'DMAP_ERY5': ['ECT2',
#   'GYPB',
#   'SELENBP1',
#   'MPP1',
#   'GLUL',
#   'KLF1',
#   'PDCD10',
#   'FBXO34',
#   'PQLC1',
#   'NPL',
#   'ADIPOR1',
#   'TOP1',
#   'ARF1',
#   'CALCOCO1',
#   'POLR1D',
#   'RALBP1',
#   'ANK1',
#   'MBOAT2',
#   'DDB1',
#   'ZBTB17',
#   'NINJ2',
#   'TFR2',
#   'CREG1',
#   'HPS1',
#   'WIPI2',
#   'CDC27',
#   'PSMF1',
#   'PTTG1',
#   'MAP2K3',
#   'TSG101',
#   'FZD5',
#   'HIGD1A',
#   'GYPE',
#   'RMND5A',
#   'TTLL12',
#   'DNAJC6',
#   'H1F0',
#   'UBE2V1',
#   'C1D',
#   'LGALS3',
#   'SERPINI1',
#   'SAMD9',
#   'TUFT1',
#   'MICAL2',
#   'GABARAPL1',
#   'GFOD2',
#   'UBAP1',
#   'MXI1',
#   'SLC16A1',
#   'BLVRB',
#   'KIDINS220',
#   'DCUN1D1',
#   'ARL6IP1',
#   'CCNB2',
#   'E2F4',
#   'RNF10',
#   'PLEK2',
#   'SPTB',
#   'ARL4A',
#   'ARF4',
#   'DOHH',
#   'BPGM'],
#  'DMAP_GMP': ['CPA3', 'F13A1'],
#  'DMAP_GRAN1': ['GAL3ST4',
#   'MEST',
#   'PRKCH',
#   'IL32',
#   'CD79A',
#   'PEG10',
#   'BANK1',
#   'P2RX5',
#   'CR2',
#   'RASGRP3',
#   'CD28'],
#  'DMAP_GRAN2': ['ALDH2',
#   'FXYD6',
#   'TSPO',
#   'HBEGF',
#   'HCK',
#   'MS4A3',
#   'ANXA5',
#   'CLEC4A',
#   'CASP1',
#   'SERPINA1',
#   'SIRPB1',
#   'QPCT',
#   'MNDA',
#   'EPS8',
#   'WDFY3',
#   'STEAP4',
#   'SLC31A2',
#   'TMEM176B',
#   'FGL2'],
#  'DMAP_GRAN3': ['CEACAM8',
#   'CASP1',
#   'FCGR3A',
#   'FCN1',
#   'TSPO',
#   'SCO2',
#   'FGL2',
#   'TCN1',
#   'RIN2',
#   'MAFB',
#   'HAL',
#   'KIAA1598',
#   'IFI30',
#   'CLEC7A',
#   'CD93',
#   'KLRK1',
#   'TCF7L2',
#   'PADI2',
#   'MYB',
#   'ZAP70',
#   'NCF2'],
#  'DMAP_HSC1': ['KIT',
#   'PDGFD',
#   'ALDH1A1',
#   'CACNB2',
#   'MEIS1',
#   'SPRED2',
#   'ANGPT1',
#   'JUP',
#   'HLF',
#   'FXYD6',
#   'PBX1'],
#  'DMAP_HSC3': ['HLF',
#   'JUP',
#   'CDCP1',
#   'SOCS2',
#   'KIAA0125',
#   'IGJ',
#   'STK32B',
#   'FLT3',
#   'IL18',
#   'SLC39A8',
#   'FXYD6',
#   'LAPTM4B'],
#  'DMAP_MEGA1': ['MEIS1', 'GATA2', 'FSTL1'],
#  'DMAP_MEGA2': ['CD8A',
#   'DCLRE1A',
#   'F13A1',
#   'PDGFA',
#   'SELP',
#   'PF4V1',
#   'COL6A3',
#   'GP1BA'],
#  'DMAP_MEP': ['DTL',
#   'MYL6',
#   'SLC39A8',
#   'PLAGL1',
#   'TFRC',
#   'SPINK2',
#   'POLE',
#   'PBX1'],
#  'DMAP_MONO1': ['TNFAIP2',
#   'LTF',
#   'SMPDL3A',
#   'MPO',
#   'APOBEC3A',
#   'HMOX1',
#   'P2RY13',
#   'SULT1A1',
#   'EMR1',
#   'DEFA4',
#   'LGALS2',
#   'TSPO',
#   'CD9',
#   'F13A1',
#   'SLC31A2',
#   'FGL2'],
#  'DMAP_MONO2': ['MS4A6A',
#   'PYGL',
#   'SLC7A7',
#   'EPS8',
#   'CYP1B1',
#   'TNFRSF1B',
#   'CD93',
#   'DUSP6',
#   'CRISPLD2',
#   'CYP27A1',
#   'TFEC',
#   'STEAP4',
#   'DSC2',
#   'CSF1',
#   'CST3',
#   'FXYD6',
#   'S100A9',
#   'KCNJ2',
#   'HCK',
#   'BST1',
#   'QPCT'],
#  'DMAP_NKA1': ['SLC31A2',
#   'IFI30',
#   'SMPDL3A',
#   'TCF7L2',
#   'SIRPB1',
#   'TBC1D8',
#   'ABCC3',
#   'WDFY3',
#   'SLC7A7',
#   'VPS53'],
#  'DMAP_NKA2': ['ADRB2',
#   'KLRC1',
#   'GNLY',
#   'ERBB2',
#   'PAFAH2',
#   'B3GAT1',
#   'PRSS23',
#   'NCALD',
#   'PDGFD',
#   'MYOM2',
#   'TXK',
#   'PRF1'],
#  'DMAP_NKA3': ['CDC25B',
#   'XCL1',
#   'CTSW',
#   'TBX21',
#   'TNFRSF11A',
#   'EFHC2',
#   'CD8A',
#   'CRTAM'],
#  'DMAP_PRE_BCELL3': ['TNFRSF17', 'CD79B'],
#  'DMAP_TCELLA1': ['RARRES3',
#   'ITK',
#   'COPZ2',
#   'CD3D',
#   'CRTAM',
#   'PRKCQ',
#   'ADRB2',
#   'IL2RB'],
#  'DMAP_TCELLA2': ['SCML1',
#   'LDLR',
#   'IL11RA',
#   'PASK',
#   'PCSK5',
#   'FAM102A',
#   'DGKA',
#   'CD28',
#   'TBC1D4',
#   'SLC16A10',
#   'DENND2D',
#   'KLRK1'],
#  'DMAP_TCELLA3': ['GZMK',
#   'RARRES3',
#   'CD3E',
#   'TRAT1',
#   'IL32',
#   'NELL2',
#   'SYNE2',
#   'TBX21',
#   'MYB',
#   'ME1'],
#  'DMAP_TCELLA4': ['CD3D',
#   'NR3C2',
#   'ZAP70',
#   'MYB',
#   'CD8A',
#   'CD8B',
#   'KLRK1',
#   'NELL2'],
#  'DMAP_TCELLA6': ['FHIT',
#   'NR3C2',
#   'LRIG1',
#   'FAM102A',
#   'TRAT1',
#   'NOSIP',
#   'PRKCQ',
#   'ICOS',
#   'CDC25B',
#   'CD28',
#   'IL7R'],
#  'DMAP_TCELLA7': ['CD3E', 'CD3G', 'CAMTA1', 'NELL2', 'ICOS', 'SKAP1', 'IL32'],
#  'DMAP_TCELLA8': ['TRAT1',
#   'SYNE2',
#   'ST8SIA1',
#   'CD3G',
#   'DPP4',
#   'IL7R',
#   'MAN1C1',
#   'ITK'],
#  'IRIS_Bcell-Memory_IgG_IgA': ['SPDYE1',
#   'HEY1',
#   'FCRL1',
#   'AFF3',
#   'COCH',
#   'PARM1',
#   'MS4A1',
#   'KIAA0125',
#   'E2F5',
#   'SLC15A2',
#   'COBLL1',
#   'DENND5B'],
#  'IRIS_Bcell-Memory_IgM': ['HLA-DOA',
#   'BCL11A',
#   'AFF3',
#   'TCF4',
#   'COBLL1',
#   'FAM129C',
#   'QRSL1',
#   'PAX5',
#   'PKIG',
#   'BLNK',
#   'SLC4A4',
#   'TPD52'],
#  'IRIS_Bcell-naive': ['RALGPS2',
#   'MEF2C',
#   'E2F5',
#   'CR2',
#   'HHEX',
#   'CPNE5',
#   'GGA2',
#   'COBLL1',
#   'CD72',
#   'PAX5',
#   'PAWR',
#   'CD22',
#   'PEG10',
#   'CR1'],
#  'IRIS_CD4Tcell-N0': ['LDLR', 'EPPK1', 'TXK', 'TLE2', 'CD160', 'PASK', 'SNPH'],
#  'IRIS_CD4Tcell-Th1-restimulated12hour': ['UBASH3A',
#   'IFNG',
#   'BUB1B',
#   'TMEM97'],
#  'IRIS_CD4Tcell-Th1-restimulated48hour': ['CTLA4',
#   'CPOX',
#   'TMEM97',
#   'IFNG',
#   'CENPF'],
#  'IRIS_CD4Tcell-Th2-restimulated12hour': ['CEP55',
#   'NPHP4',
#   'IFNG',
#   'TPRG1',
#   'NDFIP2'],
#  'IRIS_CD4Tcell-Th2-restimulated48hour': ['CKAP2L',
#   'BAG2',
#   'FOXM1',
#   'UBASH3A',
#   'RRM2',
#   'BUB1'],
#  'IRIS_CD8Tcell-N0': ['KLRF1',
#   'MYBL1',
#   'PLEKHB1',
#   'NR3C2',
#   'CD8A',
#   'CD160',
#   'MYB'],
#  'IRIS_DendriticCell-Control': ['FAM198B',
#   'RGS1',
#   'SLC7A11',
#   'ARHGAP18',
#   'ST3GAL6',
#   'FCER1A',
#   'CTTNBP2NL',
#   'DFNA5',
#   'PARM1',
#   'GAS6',
#   'RAB20',
#   'HLA-DQA1',
#   'PILRA',
#   'TGFBI',
#   'NFXL1',
#   'F13A1',
#   'MGST1',
#   'A2M',
#   'TLR4',
#   'ARRDC4',
#   'B3GNT5',
#   'MRAS',
#   'LHFPL2',
#   'DOCK4',
#   'RGL1',
#   'C1QA',
#   'SULF2',
#   'SLC48A1',
#   'GAS2L1',
#   'SLC38A6',
#   'SLAMF8',
#   'RTN1',
#   'PAK1',
#   'ME1'],
#  'IRIS_DendriticCell-LPSstimulated': ['DNAJB4',
#   'CMPK2',
#   'CLIC2',
#   'PSD3',
#   'IL8',
#   'ABTB2',
#   'CREB5',
#   'ATP6V1H',
#   'G0S2',
#   'NQO1',
#   'SRD5A3',
#   'CHST7',
#   'ABCA6',
#   'IFIT2',
#   'CD274',
#   'L3MBTL4',
#   'ZG16B',
#   'TFEC',
#   'TNFSF4',
#   'PILRA',
#   'TOMM34',
#   'FSCN1',
#   'ELOVL7',
#   'IL15RA',
#   'CSTA',
#   'CD1E',
#   'MAP3K6',
#   'PALLD',
#   'TGM2',
#   'RIPK2',
#   'GAS2',
#   'KIAA1598',
#   'SDC2',
#   'DHX58',
#   'HOMER2',
#   'IFI44L',
#   'C1QB',
#   'NFKBID',
#   'SPI1',
#   'ARHGAP22',
#   'PLAU'],
#  'IRIS_MemoryTcell-RO-activated': ['TPR',
#   'JAKMIP1',
#   'CCNB2',
#   'TPRG1',
#   'WDHD1',
#   'FAM83D'],
#  'IRIS_MemoryTcell-RO-unactivated': ['TMEM204',
#   'FAM134B',
#   'MEOX1',
#   'VIPR1',
#   'TCEA3',
#   'PASK'],
#  'IRIS_Monocyte-Day0': ['IRAK3',
#   'MAP3K3',
#   'VPS37C',
#   'CD163',
#   'SPI1',
#   'RAB3D',
#   'IL15',
#   'CD93',
#   'CREB5',
#   'SLC11A1',
#   'CSF3R',
#   'LILRA2',
#   'MS4A7',
#   'ANG',
#   'SMARCD3',
#   'S100A12',
#   'RGS18',
#   'SULT1A2',
#   'MAFB',
#   'LPCAT2',
#   'FBN2',
#   'NLRP3',
#   'FTH1',
#   'RBP7',
#   'CPVL',
#   'CDC42',
#   'C5AR1',
#   'PADI4',
#   'VNN1',
#   'CD14',
#   'HK3',
#   'SIRPA',
#   'CARD9',
#   'ZNF503',
#   'MEF2C',
#   'EMR2'],
#  'IRIS_Monocyte-Day1': ['C3',
#   'HBEGF',
#   'ABCA1',
#   'IDO1',
#   'HIP1',
#   'ZC3H12C',
#   'DRAM1',
#   'MMP14',
#   'WDFY3',
#   'LAMP3',
#   'THBS1',
#   'SLC22A1',
#   'IRAK2',
#   'NEDD4L',
#   'DMXL2',
#   'LAMB3',
#   'S1PR3',
#   'CDC42BPB',
#   'HECW2',
#   'LRP12',
#   'NQO1',
#   'ARRDC4',
#   'TNFAIP2',
#   'EMR2',
#   'S100A8',
#   'PILRA',
#   'SLC1A3',
#   'S100A9',
#   'KCTD12',
#   'EPB41L3',
#   'LILRA2',
#   'AKR1C3',
#   'MREG',
#   'TGM2',
#   'CTTNBP2NL',
#   'ABCC3',
#   'SPI1',
#   'DOCK4',
#   'NAMPT',
#   'CCDC88A',
#   'C5AR1',
#   'TMEM158'],
#  'IRIS_Monocyte-Day7': ['NME7',
#   'WDFY3',
#   'MARCO',
#   'KCNE3',
#   'C1QA',
#   'ATP6V1H',
#   'GPC4',
#   'KCNE1',
#   'SLA',
#   'CSF1R',
#   'HNMT',
#   'SDC2',
#   'EMP1',
#   'A2M',
#   'DUSP3',
#   'SPOCD1',
#   'PLAUR',
#   'PRAM1',
#   'NCEH1',
#   'RASAL2',
#   'CA2',
#   'AKR1C3',
#   'DOCK4',
#   'RTN1',
#   'GAS2L1',
#   'NRP1',
#   'OLFML2B',
#   'ACO1',
#   'ALOX5',
#   'BLVRB',
#   'CSTA',
#   'FGD4',
#   'PSD3',
#   'DMXL2',
#   'PSD',
#   'DAB2',
#   'MS4A7',
#   'CXCL5',
#   'MRAS',
#   'GPX3'],
#  'IRIS_NKcell-IL15stimulated': ['IL12RB2',
#   'ATP9A',
#   'NDFIP2',
#   'XCL1',
#   'PDGFRB',
#   'CX3CR1',
#   'MYBL1'],
#  'IRIS_NKcell-IL2stimulated': ['SLCO4C1',
#   'IFNG',
#   'NDFIP2',
#   'AKR1C3',
#   'ELOVL6',
#   'GNAL',
#   'KIR3DL1'],
#  'IRIS_NKcell-control': ['KLRD1',
#   'NCAM1',
#   'KIR3DL1',
#   'IL12RB2',
#   'ATP9A',
#   'LCN2',
#   'PLBD1',
#   'SLCO4C1',
#   'YPEL1'],
#  'IRIS_Neutrophil-Resting': ['CFD',
#   'RAB20',
#   'CR1',
#   'PPCDC',
#   'PTPRN',
#   'RGS1',
#   'SOD2',
#   'CLC',
#   'PHOSPHO1',
#   'SECTM1',
#   'RNF24',
#   'CSF3R',
#   'CD93',
#   'THBD',
#   'BST1',
#   'ZNF467',
#   'AMPD2',
#   'GCA',
#   'PRICKLE1',
#   'S100P',
#   'NCF2',
#   'CYHR1',
#   'LPCAT2',
#   'MANSC1',
#   'CCR3',
#   'PRAM1',
#   'PPP1R12B',
#   'LILRA4',
#   'CYP4F3',
#   'ARAP3',
#   'RNASE2',
#   'MSL1',
#   'UBE2B',
#   'LRRC4',
#   'LPAR2',
#   'MPZ',
#   'WDFY3',
#   'CD9',
#   'LRRK2',
#   'CFP',
#   'SLC4A4',
#   'TLR1',
#   'SULT1B1',
#   'HIST1H2AC',
#   'CRISPLD2',
#   'GMFG',
#   'TMEM154',
#   'B3GNT5',
#   'NFE2',
#   'TLR6',
#   'TMEM91',
#   'RASGRP4',
#   'S100A8',
#   'CASP5',
#   'TNFAIP2',
#   'CXCL16',
#   'PILRA'],
#  'IRIS_PlasmaCell-FromBoneMarrow': ['ATF3',
#   'EAF2',
#   'SLC31A2',
#   'MYO1D',
#   'MERTK',
#   'B3GNT1',
#   'PICK1',
#   'TXNDC15',
#   'RAB30',
#   'COL4A3',
#   'TMEM220',
#   'CNKSR1',
#   'ZNF275',
#   'CPNE5',
#   'KIAA0125',
#   'NT5DC2',
#   'PLTP',
#   'YES1',
#   'UAP1'],
#  'IRIS_PlasmaCell-FromPBMC': ['ZNF341',
#   'RAB30',
#   'DERL3',
#   'NBEA',
#   'ZBP1',
#   'CAD',
#   'TXNDC11',
#   'BUB1B',
#   'PDIA5',
#   'PREB',
#   'PAX5',
#   'BLNK',
#   'DENND5B',
#   'MAGED1',
#   'C2orf88'],
#  'KEGG_ABC_TRANSPORTERS': ['ABCG2', 'ABCC6', 'ABCC4', 'ABCB9', 'ABCA5'],
#  'KEGG_ACUTE_MYELOID_LEUKEMIA': ['LEF1',
#   'PIK3CG',
#   'MAP2K1',
#   'HRAS',
#   'PIM2',
#   'KRAS',
#   'AKT3',
#   'PIM1',
#   'NFKB1',
#   'BRAF'],
#  'KEGG_ADHERENS_JUNCTION': ['WASF2',
#   'TCF7L2',
#   'CTNND1',
#   'SNAI1',
#   'RAC3',
#   'WASF3',
#   'NLK',
#   'YES1',
#   'PTPN1',
#   'FYN',
#   'CSNK2B',
#   'CSNK2A1'],
#  'KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY': ['TNFRSF1A',
#   'ACSL6',
#   'PCK2',
#   'IRS1',
#   'PPARA',
#   'AKT2',
#   'AKT1',
#   'ACSL5',
#   'ADIPOR1',
#   'ACSL1'],
#  'KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION': ['PIK3R5',
#   'ATP1A1',
#   'SCNN1A',
#   'ATP1B3',
#   'PIK3CA'],
#  'KEGG_ALLOGRAFT_REJECTION': ['CD40', 'HLA-F', 'GZMB', 'CD28', 'HLA-DMA'],
#  'KEGG_ALZHEIMERS_DISEASE': ['ATP5J',
#   'MME',
#   'NDUFB7',
#   'NDUFS5',
#   'PLCB3',
#   'ITPR3',
#   'ATP5E',
#   'UQCRFS1',
#   'ATP5F1',
#   'APBB1',
#   'NDUFA1',
#   'TNFRSF1A',
#   'PSENEN',
#   'CASP7',
#   'NDUFS4',
#   'NDUFA3',
#   'NDUFA10',
#   'COX5A',
#   'APH1A',
#   'PSEN2',
#   'CDK5',
#   'PPP3CA',
#   'UQCRC1',
#   'BACE2',
#   'PPP3CB',
#   'SDHA'],
#  'KEGG_AMINOACYL_TRNA_BIOSYNTHESIS': ['PSTK',
#   'IARS',
#   'CARS',
#   'WARS2',
#   'SEPSECS',
#   'IARS2',
#   'EARS2'],
#  'KEGG_AMINO_SUGAR_AND_NUCLEOTIDE_SUGAR_METABOLISM': ['GPI',
#   'GFPT1',
#   'NANS',
#   'TSTA3',
#   'CYB5R1',
#   'PGM2',
#   'CYB5R3'],
#  'KEGG_AMYOTROPHIC_LATERAL_SCLEROSIS_ALS': ['CASP3',
#   'DAXX',
#   'PPP3CC',
#   'MAPK13',
#   'CAT',
#   'SOD1',
#   'BAX'],
#  'KEGG_ANTIGEN_PROCESSING_AND_PRESENTATION': ['CTSS',
#   'HLA-G',
#   'HSPA5',
#   'HLA-DRB5',
#   'KIR2DL4',
#   'NFYA',
#   'NFYB',
#   'CD4',
#   'HLA-DPA1',
#   'HSP90AA1',
#   'HLA-DPB1',
#   'KLRC3'],
#  'KEGG_APOPTOSIS': ['RIPK1',
#   'IRAK4',
#   'FASLG',
#   'CASP8',
#   'NFKBIA',
#   'PIK3CG',
#   'RELA',
#   'TP53',
#   'PRKAR1B',
#   'BCL2',
#   'PPP3CA',
#   'AIFM1',
#   'TNFRSF1A',
#   'TNFRSF10A',
#   'CAPN2'],
#  'KEGG_ARACHIDONIC_ACID_METABOLISM': ['GPX4',
#   'GGT1',
#   'GPX7',
#   'ALOX15B',
#   'LTA4H'],
#  'KEGG_ARGININE_AND_PROLINE_METABOLISM': ['PYCR1',
#   'GATM',
#   'GLS',
#   'ALDH4A1',
#   'GLUD1',
#   'LAP3'],
#  'KEGG_ARRHYTHMOGENIC_RIGHT_VENTRICULAR_CARDIOMYOPATHY_ARVC': ['ITGA3',
#   'ITGAV',
#   'TCF7L1',
#   'CACNG6',
#   'ITGB1',
#   'ACTN1',
#   'SLC8A1',
#   'CACNB3'],
#  'KEGG_AUTOIMMUNE_THYROID_DISEASE': ['CTLA4',
#   'HLA-E',
#   'HLA-DPA1',
#   'FASLG',
#   'HLA-B'],
#  'KEGG_AXON_GUIDANCE': ['NFATC3',
#   'MAPK1',
#   'KRAS',
#   'SEMA4G',
#   'PLXNB1',
#   'EPHA1',
#   'NFAT5',
#   'GNAI3',
#   'EPHB2',
#   'SEMA4F',
#   'FYN',
#   'EPHA2',
#   'NRP1',
#   'GSK3B',
#   'ABLIM3',
#   'PPP3R1',
#   'SEMA4D'],
#  'KEGG_BASAL_CELL_CARCINOMA': ['DVL1', 'WNT5B', 'DVL3', 'TCF7', 'TCF7L2'],
#  'KEGG_BASAL_TRANSCRIPTION_FACTORS': ['GTF2F1',
#   'GTF2A2',
#   'GTF2I',
#   'GTF2H1',
#   'TAF5'],
#  'KEGG_BASE_EXCISION_REPAIR': ['XRCC1',
#   'POLD4',
#   'POLL',
#   'APEX1',
#   'POLE',
#   'POLD3'],
#  'KEGG_BLADDER_CANCER': ['RASSF1',
#   'ERBB2',
#   'VEGFB',
#   'DAPK1',
#   'VEGFA',
#   'THBS1',
#   'E2F2'],
#  'KEGG_B_CELL_RECEPTOR_SIGNALING_PATHWAY': ['PPP3CC',
#   'RELA',
#   'CD81',
#   'RASGRP3',
#   'PPP3R1',
#   'VAV1',
#   'IFITM1',
#   'NFKBIE',
#   'MAPK3',
#   'IKBKG',
#   'CARD11',
#   'NFATC2',
#   'MAPK1',
#   'NFKBIA'],
#  'KEGG_CALCIUM_SIGNALING_PATHWAY': ['PPP3CB',
#   'PRKCB',
#   'MYLK',
#   'CACNA1E',
#   'CD38',
#   'GRIN2C',
#   'PRKCA',
#   'CAMK4',
#   'ITPR3',
#   'CACNA1F',
#   'ATP2A2',
#   'ADORA2B',
#   'CALM2',
#   'GNA15',
#   'P2RX6',
#   'PHKA2',
#   'PPP3CA',
#   'CACNA1H'],
#  'KEGG_CARDIAC_MUSCLE_CONTRACTION': ['COX6B1',
#   'ATP1B1',
#   'SLC9A6',
#   'CACNA2D4',
#   'ATP1B3',
#   'COX7B',
#   'CACNB4',
#   'CACNG6'],
#  'KEGG_CELL_ADHESION_MOLECULES_CAMS': ['CNTNAP2',
#   'PTPRM',
#   'MPZ',
#   'CLDN9',
#   'CD34',
#   'ICAM1',
#   'HLA-DRA',
#   'CADM1',
#   'ICOSLG',
#   'SIGLEC1',
#   'PVRL2',
#   'PTPRC',
#   'HLA-B',
#   'NRCAM',
#   'ITGA4',
#   'ICOS',
#   'JAM3'],
#  'KEGG_CELL_CYCLE': ['E2F2',
#   'CDC23',
#   'MCM6',
#   'PCNA',
#   'EP300',
#   'CDKN2B',
#   'ORC3',
#   'CHEK2',
#   'WEE1',
#   'TP53',
#   'CCNB2',
#   'CDC27',
#   'ATR',
#   'CDKN1A',
#   'ORC1',
#   'PKMYT1',
#   'YWHAE',
#   'BUB1B',
#   'HDAC1',
#   'YWHAZ',
#   'RBL2',
#   'CDC14B'],
#  'KEGG_CHEMOKINE_SIGNALING_PATHWAY': ['PTK2B',
#   'SHC1',
#   'CCR4',
#   'ADCY7',
#   'STAT3',
#   'MAPK1',
#   'PIK3CD',
#   'RELA',
#   'IKBKG',
#   'GRK4',
#   'JAK3',
#   'WASL',
#   'GNG11',
#   'WAS',
#   'RAC2',
#   'XCL1',
#   'RAC1',
#   'PAK1',
#   'SOS2',
#   'GNAI1',
#   'IL8',
#   'CCL5',
#   'GNB4',
#   'NFKB1',
#   'CCR10',
#   'HCK'],
#  'KEGG_CHRONIC_MYELOID_LEUKEMIA': ['ABL1',
#   'NFKBIA',
#   'CHUK',
#   'PIK3R3',
#   'SOS2',
#   'PIK3CG',
#   'CTBP1',
#   'PTPN11',
#   'AKT3',
#   'GRB2',
#   'RB1',
#   'CBLB',
#   'BRAF'],
#  'KEGG_COLORECTAL_CANCER': ['SMAD3',
#   'ARAF',
#   'JUN',
#   'PIK3CG',
#   'MSH3',
#   'RHOA',
#   'PIK3CB',
#   'PIK3R3',
#   'MAPK9',
#   'CASP9',
#   'MAPK8'],
#  'KEGG_COMPLEMENT_AND_COAGULATION_CASCADES': ['C1S',
#   'PLAT',
#   'PLAU',
#   'SERPINA1',
#   'VWF',
#   'C1QB',
#   'CD46'],
#  'KEGG_CYSTEINE_AND_METHIONINE_METABOLISM': ['LDHA', 'MAT2A', 'MAT2B', 'ADI1'],
#  'KEGG_CYTOKINE_CYTOKINE_RECEPTOR_INTERACTION': ['ACVR2A',
#   'CCR2',
#   'TNFRSF13B',
#   'IL1R1',
#   'EDAR',
#   'CD27',
#   'TNFRSF10B',
#   'VEGFA',
#   'FLT3LG',
#   'IL13RA1',
#   'CXCL16',
#   'CLCF1',
#   'LTA',
#   'FAS',
#   'OSM',
#   'HGF',
#   'CXCR5',
#   'TNFRSF1B',
#   'TGFB1',
#   'CX3CR1',
#   'FLT4',
#   'TNFSF14',
#   'PDGFC',
#   'IL12RB1',
#   'IL2RA',
#   'IL6ST',
#   'TNFRSF4'],
#  'KEGG_CYTOSOLIC_DNA_SENSING_PATHWAY': ['POLR3B',
#   'TMEM173',
#   'DDX58',
#   'NFKB1',
#   'ADAR',
#   'CXCL10',
#   'POLR3F'],
#  'KEGG_DILATED_CARDIOMYOPATHY': ['ITGB1',
#   'CACNB3',
#   'ATP2A2',
#   'CACNG6',
#   'LMNA',
#   'TNF',
#   'ITGA6',
#   'SLC8A1',
#   'CACNB1',
#   'DAG1'],
#  'KEGG_DNA_REPLICATION': ['LIG1',
#   'POLE2',
#   'FEN1',
#   'MCM2',
#   'RFC3',
#   'POLD4',
#   'MCM4'],
#  'KEGG_ECM_RECEPTOR_INTERACTION': ['THBS1',
#   'SPP1',
#   'COL6A2',
#   'CHAD',
#   'ITGAV',
#   'ITGB5',
#   'ITGB7',
#   'VWF',
#   'SV2A',
#   'GP5'],
#  'KEGG_ENDOCYTOSIS': ['HLA-F',
#   'PIP5K1A',
#   'RABEP1',
#   'CXCR2',
#   'SH3GLB2',
#   'ADRBK1',
#   'PARD6G',
#   'CDC42',
#   'ADRB2',
#   'RNF41',
#   'HLA-G',
#   'PARD3',
#   'HSPA1B',
#   'ARFGAP3',
#   'CCR5',
#   'HLA-C',
#   'ITCH',
#   'PLD2',
#   'CXCR1',
#   'VPS37B',
#   'SRC',
#   'ARAP2',
#   'VPS37A',
#   'CHMP4B',
#   'EHD4',
#   'DAB2',
#   'RAB31',
#   'GRK5',
#   'WWP1',
#   'GRK6',
#   'SMAP2'],
#  'KEGG_ENDOMETRIAL_CANCER': ['CTNNA1',
#   'CCND1',
#   'BRAF',
#   'NRAS',
#   'TCF7L1',
#   'CTNNB1',
#   'PIK3CB',
#   'SOS1',
#   'APC2'],
#  'KEGG_EPITHELIAL_CELL_SIGNALING_IN_HELICOBACTER_PYLORI_INFECTION': ['MAPK14',
#   'ATP6V0E2',
#   'CDC42',
#   'NOD1',
#   'LYN',
#   'RAC1',
#   'CXCR1',
#   'JUN',
#   'PLCG2',
#   'ATP6V1H',
#   'RELA'],
#  'KEGG_ERBB_SIGNALING_PATHWAY': ['RPS6KB2',
#   'PIK3R3',
#   'SOS1',
#   'AKT1',
#   'GSK3B',
#   'TGFA',
#   'KRAS',
#   'JUN',
#   'SOS2',
#   'STAT5A',
#   'PIK3CG',
#   'NRAS',
#   'MAP2K4'],
#  'KEGG_FATTY_ACID_METABOLISM': ['ALDH3A2', 'ACSL3', 'ALDH2', 'ACADS', 'ADH5'],
#  'KEGG_FC_EPSILON_RI_SIGNALING_PATHWAY': ['PIK3CA',
#   'TNF',
#   'PLCG1',
#   'MAP2K4',
#   'LAT',
#   'MAPK8',
#   'BTK',
#   'PIK3R3',
#   'INPP5D',
#   'PDK1',
#   'FCER1G'],
#  'KEGG_FC_GAMMA_R_MEDIATED_PHAGOCYTOSIS': ['FCGR2B',
#   'PLA2G4A',
#   'CFL1',
#   'CRKL',
#   'SPHK1',
#   'WAS',
#   'ARF6',
#   'PIK3CG',
#   'WASF1',
#   'LIMK1',
#   'DNM1',
#   'PLD2',
#   'VASP',
#   'ARPC5L',
#   'PIK3R3',
#   'PIP5K1B',
#   'DNM2'],
#  'KEGG_FOCAL_ADHESION': ['FLT4',
#   'CCND2',
#   'SOS2',
#   'AKT1',
#   'PDGFB',
#   'CCND3',
#   'CAPN2',
#   'CTNNB1',
#   'LAMC1',
#   'LAMC3',
#   'BAD',
#   'ACTN1',
#   'ACTN4',
#   'ROCK2',
#   'THBS4',
#   'XIAP',
#   'FLNB',
#   'PDGFRB',
#   'CAV2',
#   'MAPK3',
#   'PIK3R5',
#   'FLNA',
#   'VEGFA',
#   'VWF',
#   'ELK1',
#   'FLT1',
#   'PAK4'],
#  'KEGG_FRUCTOSE_AND_MANNOSE_METABOLISM': ['GMPPA',
#   'PMM1',
#   'PFKFB4',
#   'AKR1B1',
#   'SORD'],
#  'KEGG_GAP_JUNCTION': ['GNAI2',
#   'LPAR1',
#   'PDGFA',
#   'ADCY6',
#   'TUBA1A',
#   'TUBB2A',
#   'MAP3K2',
#   'ITPR2',
#   'GNAS',
#   'PLCB3',
#   'CDK1'],
#  'KEGG_GLIOMA': ['CALM3',
#   'MAPK3',
#   'PIK3R1',
#   'CDK6',
#   'PIK3CB',
#   'RB1',
#   'AKT3',
#   'AKT2',
#   'CDK4',
#   'MDM2'],
#  'KEGG_GLUTATHIONE_METABOLISM': ['MGST1',
#   'GSR',
#   'IDH2',
#   'SRM',
#   'GPX4',
#   'GSTO1',
#   'G6PD'],
#  'KEGG_GLYCEROLIPID_METABOLISM': ['AGPAT9',
#   'ALDH2',
#   'AGPAT6',
#   'CEL',
#   'ALDH3A2',
#   'DGKE'],
#  'KEGG_GLYCEROPHOSPHOLIPID_METABOLISM': ['AGPAT9',
#   'PLD2',
#   'GNPAT',
#   'PLA2G15',
#   'LPGAT1',
#   'PLA2G12A',
#   'AGPAT1',
#   'AGPAT6',
#   'DGKE',
#   'PCYT1B',
#   'LPCAT3'],
#  'KEGG_GLYCOLYSIS_GLUCONEOGENESIS': ['HK1',
#   'PCK2',
#   'ALDOC',
#   'PGAM1',
#   'BPGM',
#   'ADH5',
#   'ALDH3A2'],
#  'KEGG_GNRH_SIGNALING_PATHWAY': ['CALM3',
#   'PRKACB',
#   'MAP3K1',
#   'JUN',
#   'MAPK7',
#   'MAPK9',
#   'ITPR3',
#   'MAP2K1',
#   'CAMK2G',
#   'PLA2G4A',
#   'RAF1',
#   'HRAS',
#   'SRC'],
#  'KEGG_GRAFT_VERSUS_HOST_DISEASE': ['HLA-DRB5',
#   'HLA-C',
#   'HLA-DOA',
#   'HLA-DPB1',
#   'KLRC1',
#   'CD28'],
#  'KEGG_HEDGEHOG_SIGNALING_PATHWAY': ['CSNK1G1',
#   'CSNK1D',
#   'WNT10B',
#   'STK36',
#   'FBXW11'],
#  'KEGG_HEMATOPOIETIC_CELL_LINEAGE': ['GP9',
#   'ITGAM',
#   'CD9',
#   'CD37',
#   'FLT3',
#   'ITGA6',
#   'IL2RA',
#   'CD14',
#   'GP1BA',
#   'CD3D',
#   'IL1R1',
#   'CD2',
#   'CD7'],
#  'KEGG_HUNTINGTONS_DISEASE': ['POLR2A',
#   'SOD1',
#   'COX5B',
#   'NDUFA6',
#   'EP300',
#   'PLCB2',
#   'SDHC',
#   'SDHD',
#   'NDUFV2',
#   'UQCRC2',
#   'NDUFB2',
#   'ATP5E',
#   'PLCB1',
#   'GNAQ',
#   'NDUFS2',
#   'CLTB',
#   'UQCRB',
#   'CASP8',
#   'COX4I1',
#   'NDUFB3',
#   'NDUFA2',
#   'AP2A1',
#   'BAX',
#   'ATP5G1',
#   'UQCRQ',
#   'SP1',
#   'COX7A2',
#   'SDHA'],
#  'KEGG_HYPERTROPHIC_CARDIOMYOPATHY_HCM': ['ITGA5',
#   'CACNA1F',
#   'TTN',
#   'ATP2A2',
#   'MYBPC3',
#   'DAG1',
#   'ITGA10',
#   'ITGA3',
#   'PRKAB1'],
#  'KEGG_INOSITOL_PHOSPHATE_METABOLISM': ['PIKFYVE',
#   'TPI1',
#   'PLCD3',
#   'PI4KB',
#   'PTEN',
#   'PLCB3',
#   'PI4KA',
#   'PLCD1',
#   'PLCB2'],
#  'KEGG_INSULIN_SIGNALING_PATHWAY': ['PRKAG1',
#   'CBL',
#   'PCK2',
#   'MKNK2',
#   'ELK1',
#   'PPP1R3B',
#   'PHKB',
#   'TSC1',
#   'HRAS',
#   'RPS6KB1',
#   'TRIP10',
#   'PRKAR1B',
#   'EIF4E2',
#   'PRKX',
#   'RPTOR',
#   'PRKAG2',
#   'PIK3CB',
#   'SOCS3',
#   'PPP1CA',
#   'MTOR',
#   'SOCS4'],
#  'KEGG_INTESTINAL_IMMUNE_NETWORK_FOR_IGA_PRODUCTION': ['IL15RA',
#   'TNFRSF13C',
#   'ICOSLG',
#   'CCR9',
#   'LTBR',
#   'TNFRSF13B',
#   'CD40LG'],
#  'KEGG_JAK_STAT_SIGNALING_PATHWAY': ['IL20RB',
#   'IL7R',
#   'STAT2',
#   'PIAS4',
#   'GRB2',
#   'SOS2',
#   'IFNAR1',
#   'EP300',
#   'PIK3CD',
#   'AKT2',
#   'IL4R',
#   'SOS1',
#   'MPL',
#   'JAK3',
#   'CCND2',
#   'SOCS5',
#   'IL10RA'],
#  'KEGG_LEISHMANIA_INFECTION': ['FCGR3A',
#   'HLA-DMB',
#   'NFKBIB',
#   'TLR4',
#   'HLA-DMA',
#   'IFNG',
#   'MYD88',
#   'NFKBIA',
#   'IL1B',
#   'HLA-DRB5',
#   'HLA-DRB1',
#   'RELA'],
#  'KEGG_LEUKOCYTE_TRANSENDOTHELIAL_MIGRATION': ['RHOH',
#   'CYBA',
#   'PIK3CG',
#   'ITGAL',
#   'CLDN9',
#   'PLCG2',
#   'RHOA',
#   'VAV3',
#   'ACTG1',
#   'PTPN11',
#   'ROCK1',
#   'NCF2',
#   'CTNND1',
#   'CLDN5',
#   'PXN'],
#  'KEGG_LONG_TERM_DEPRESSION': ['MAP2K2',
#   'PLA2G12A',
#   'GNAI2',
#   'ITPR2',
#   'NRAS',
#   'LYN',
#   'ITPR1',
#   'GNAQ'],
#  'KEGG_LONG_TERM_POTENTIATION': ['CALM1',
#   'PRKCA',
#   'MAPK1',
#   'PLCB1',
#   'RPS6KA1',
#   'PPP3CC',
#   'ITPR2',
#   'RAF1',
#   'ITPR1'],
#  'KEGG_LYSINE_DEGRADATION': ['PIPOX',
#   'ECHS1',
#   'SETD2',
#   'SUV39H2',
#   'SETD8',
#   'ACAT2',
#   'SUV420H1'],
#  'KEGG_LYSOSOME': ['ACP2',
#   'NEU1',
#   'NAGLU',
#   'NAGPA',
#   'NPC2',
#   'CD164',
#   'PSAP',
#   'SUMF1',
#   'AP4B1',
#   'AP3B1',
#   'ATP6V0A2',
#   'AP3S2',
#   'LAMP1',
#   'LAMP2',
#   'GGA1',
#   'LGMN',
#   'CLTC',
#   'PPT2',
#   'AP1B1',
#   'HEXB',
#   'MAN2B1',
#   'GGA2'],
#  'KEGG_MAPK_SIGNALING_PATHWAY': ['TGFBR2',
#   'CACNA1F',
#   'MAP4K3',
#   'CACNA1E',
#   'HRAS',
#   'MAP3K11',
#   'MAP3K8',
#   'HSPA1L',
#   'DUSP8',
#   'AKT2',
#   'CASP3',
#   'MAP3K13',
#   'SOS2',
#   'MAP3K1',
#   'NF1',
#   'FGF9',
#   'MAP2K2',
#   'MAPKAPK2',
#   'MAP3K5',
#   'TAOK2',
#   'DUSP2',
#   'ELK4',
#   'MAPKAPK3',
#   'IL1R2',
#   'CACNB3',
#   'DUSP16',
#   'MAP3K4',
#   'MAPK12',
#   'CACNG8',
#   'MYC',
#   'FAS',
#   'CACNA1H',
#   'RAP1A',
#   'MAP4K4',
#   'MAP3K7',
#   'TGFBR1',
#   'MAPK11',
#   'KRAS'],
#  'KEGG_MELANOGENESIS': ['PRKX',
#   'MAP2K2',
#   'GNAO1',
#   'EDN1',
#   'GNAI1',
#   'ADCY4',
#   'ADCY9',
#   'CREB3L2',
#   'MAP2K1',
#   'WNT7A',
#   'DVL3',
#   'MAPK3'],
#  'KEGG_MELANOMA': ['MAPK1',
#   'BAD',
#   'CDKN1A',
#   'KRAS',
#   'PDGFB',
#   'PTEN',
#   'E2F2',
#   'BRAF'],
#  'KEGG_METABOLISM_OF_XENOBIOTICS_BY_CYTOCHROME_P450': ['CYP1B1',
#   'CYP3A5',
#   'GSTO2',
#   'AKR1C3'],
#  'KEGG_MTOR_SIGNALING_PATHWAY': ['EIF4E',
#   'RICTOR',
#   'EIF4B',
#   'PIK3CB',
#   'MTOR',
#   'CAB39',
#   'TSC2',
#   'VEGFB'],
#  'KEGG_NATURAL_KILLER_CELL_MEDIATED_CYTOTOXICITY': ['TNFRSF10C',
#   'RAC3',
#   'CD48',
#   'PIK3CB',
#   'PLCG2',
#   'HRAS',
#   'BID',
#   'KRAS',
#   'IFNAR1',
#   'PTPN6',
#   'PRKCA',
#   'VAV1',
#   'TYROBP',
#   'KIR2DL3',
#   'PIK3CD',
#   'RAF1',
#   'HLA-E',
#   'LCK',
#   'NFATC1'],
#  'KEGG_NEUROACTIVE_LIGAND_RECEPTOR_INTERACTION': ['CHRNA10',
#   'GRIN2D',
#   'S1PR4',
#   'F2R',
#   'P2RX5',
#   'F2RL1',
#   'GRIN2C',
#   'NTSR1',
#   'PTGER2',
#   'PTGDR',
#   'GRM2',
#   'GRIN3A',
#   'NMUR1',
#   'LTB4R'],
#  'KEGG_NEUROTROPHIN_SIGNALING_PATHWAY': ['MAP3K5',
#   'SH2B2',
#   'AKT2',
#   'PRDM4',
#   'IRS1',
#   'RPS6KA5',
#   'PIK3R1',
#   'BAX',
#   'CAMK4',
#   'NGFRAP1',
#   'GSK3B',
#   'CRK',
#   'YWHAE',
#   'MAP3K3',
#   'ARHGDIB',
#   'SOS2',
#   'IKBKB',
#   'MAPK8',
#   'RHOA',
#   'RPS6KA4',
#   'YWHAB'],
#  'KEGG_NOD_LIKE_RECEPTOR_SIGNALING_PATHWAY': ['PSTPIP1',
#   'TNFAIP3',
#   'NAIP',
#   'IKBKG',
#   'MAPK3',
#   'HSP90AA1',
#   'RIPK2',
#   'NLRP1',
#   'TAB1',
#   'MAPK9'],
#  'KEGG_NON_SMALL_CELL_LUNG_CANCER': ['MAPK3',
#   'NRAS',
#   'ARAF',
#   'ERBB2',
#   'PIK3CD',
#   'RXRB',
#   'PRKCA',
#   'RASSF1',
#   'CDK6'],
#  'KEGG_NOTCH_SIGNALING_PATHWAY': ['MAML2',
#   'KAT2B',
#   'MAML3',
#   'JAG2',
#   'DTX3L',
#   'DLL1',
#   'MAML1',
#   'NCOR2'],
#  'KEGG_NUCLEOTIDE_EXCISION_REPAIR': ['XPA',
#   'CCNH',
#   'POLD2',
#   'DDB1',
#   'POLD4',
#   'POLE',
#   'RPA2',
#   'MNAT1'],
#  'KEGG_N_GLYCAN_BIOSYNTHESIS': ['MGAT1',
#   'DPAGT1',
#   'B4GALT2',
#   'MGAT4B',
#   'MGAT5',
#   'DPM3',
#   'ALG3',
#   'ALG6'],
#  'KEGG_OOCYTE_MEIOSIS': ['YWHAE',
#   'CCNB2',
#   'ADCY6',
#   'SGOL1',
#   'CCNE2',
#   'CCNE1',
#   'PPP2R1B',
#   'ITPR1',
#   'PPP2R5C',
#   'CDK1',
#   'CDK2',
#   'ADCY7',
#   'YWHAQ',
#   'YWHAB',
#   'PTTG1',
#   'PPP1CB',
#   'CALM1'],
#  'KEGG_OXIDATIVE_PHOSPHORYLATION': ['CYC1',
#   'NDUFS8',
#   'NDUFS2',
#   'ATP5A1',
#   'ATP5L',
#   'COX10',
#   'ATP6V1G1',
#   'COX7B',
#   'NDUFV3',
#   'ATP5G3',
#   'NDUFA2',
#   'COX5B',
#   'NDUFA10',
#   'NDUFB3',
#   'LHPP',
#   'UQCRC1',
#   'ATP6V1D',
#   'ATP5J2',
#   'NDUFB4',
#   'NDUFA4'],
#  'KEGG_P53_SIGNALING_PATHWAY': ['CCNB1',
#   'RFWD2',
#   'CCNG1',
#   'BBC3',
#   'STEAP3',
#   'CCNE1',
#   'MDM4',
#   'CCNB2',
#   'BAI1',
#   'CDK2',
#   'MDM2',
#   'CDK1'],
#  'KEGG_PANCREATIC_CANCER': ['AKT2',
#   'E2F1',
#   'RAD51',
#   'MAPK3',
#   'RALGDS',
#   'STAT3',
#   'VEGFB',
#   'ARHGEF6',
#   'RALA',
#   'PLD1',
#   'PGF',
#   'RELA'],
#  'KEGG_PARKINSONS_DISEASE': ['UQCRFS1',
#   'NDUFV3',
#   'NDUFA3',
#   'UBE2G1',
#   'CYC1',
#   'NDUFA4',
#   'ATP5D',
#   'ATP5E',
#   'ATP5B',
#   'VDAC2',
#   'COX5A',
#   'NDUFB6',
#   'COX7C',
#   'NDUFA8',
#   'SDHD',
#   'PPID',
#   'SNCA',
#   'NDUFS5'],
#  'KEGG_PATHOGENIC_ESCHERICHIA_COLI_INFECTION': ['ARPC5',
#   'WAS',
#   'LY9',
#   'ARPC1A',
#   'ITGB1',
#   'TUBB',
#   'TUBA1C',
#   'NCL'],
#  'KEGG_PATHWAYS_IN_CANCER': ['CRK',
#   'LAMB3',
#   'TGFBR1',
#   'DVL3',
#   'FLT3',
#   'MAPK9',
#   'FGFR1',
#   'CCND1',
#   'DAPK2',
#   'NTRK1',
#   'WNT10A',
#   'CHUK',
#   'HRAS',
#   'EGLN1',
#   'PRKCB',
#   'CTNNA1',
#   'TCF7L2',
#   'PIK3R1',
#   'RARA',
#   'RUNX1',
#   'DAPK1',
#   'BCR',
#   'CCNE2',
#   'RAD51',
#   'AKT3',
#   'PIAS1',
#   'HIF1A',
#   'MAPK3',
#   'MYC',
#   'TFG',
#   'TRAF3',
#   'PLCG1',
#   'FZD3',
#   'TGFBR2',
#   'CCDC6',
#   'RET',
#   'ARAF',
#   'CKS1B',
#   'LEF1',
#   'PDGFRB',
#   'CASP9',
#   'RAC1',
#   'BAX',
#   'STK36',
#   'ITGB1',
#   'RALB'],
#  'KEGG_PEROXISOME': ['EPHX2',
#   'CROT',
#   'PRDX5',
#   'PEX10',
#   'PEX3',
#   'GNPAT',
#   'ACSL6',
#   'IDH2',
#   'PEX2',
#   'PEX7',
#   'PEX26',
#   'ACOX1',
#   'DECR2'],
#  'KEGG_PHOSPHATIDYLINOSITOL_SIGNALING_SYSTEM': ['INPP4B',
#   'ITPR3',
#   'PI4KB',
#   'PLCD3',
#   'SYNJ2',
#   'SYNJ1',
#   'DGKE',
#   'PLCD4',
#   'PIK3R5',
#   'PIK3CA',
#   'PIK3C2B',
#   'PRKCB'],
#  'KEGG_PPAR_SIGNALING_PATHWAY': ['NR1H3',
#   'SLC27A1',
#   'SLC27A4',
#   'RXRA',
#   'SCD',
#   'SCD5',
#   'PLTP'],
#  'KEGG_PRIMARY_IMMUNODEFICIENCY': ['CD79A',
#   'IKBKG',
#   'BLNK',
#   'CD19',
#   'IL2RG',
#   'ADA'],
#  'KEGG_PROGESTERONE_MEDIATED_OOCYTE_MATURATION': ['PIK3CB',
#   'PIK3R5',
#   'MAP2K1',
#   'HSP90AA1',
#   'CDC16',
#   'PIK3CA',
#   'MAPK13',
#   'MAPK3',
#   'CDC23',
#   'ANAPC10',
#   'ADCY3',
#   'CDC27',
#   'ANAPC4'],
#  'KEGG_PROPANOATE_METABOLISM': ['PCCA', 'ACAT2', 'MLYCD', 'HIBCH', 'ACSS2'],
#  'KEGG_PROSTATE_CANCER': ['CREB3L2',
#   'HSP90B1',
#   'ATF4',
#   'TP53',
#   'CREBBP',
#   'EGF',
#   'PIK3CB',
#   'PIK3CA',
#   'MAP2K1',
#   'PDGFA',
#   'CDK2',
#   'CDKN1B',
#   'GRB2',
#   'RB1',
#   'EP300'],
#  'KEGG_PROTEASOME': ['PSMD3',
#   'PSMA6',
#   'PSMD6',
#   'PSMB7',
#   'PSMA2',
#   'PSMB9',
#   'PSMD2',
#   'PSMC5'],
#  'KEGG_PURINE_METABOLISM': ['POLE4',
#   'GMPR2',
#   'PDE7A',
#   'POLD3',
#   'POLA2',
#   'POLR3GL',
#   'ENPP3',
#   'NME3',
#   'AK5',
#   'FHIT',
#   'GMPR',
#   'PAPSS1',
#   'AK4',
#   'POLR3D',
#   'PDE1B',
#   'NUDT2',
#   'POLR3G',
#   'POLR2K',
#   'CANT1',
#   'PRIM1',
#   'POLE3',
#   'POLR3K',
#   'NME1',
#   'ENTPD4'],
#  'KEGG_PYRIMIDINE_METABOLISM': ['UCKL1',
#   'POLR3H',
#   'NT5E',
#   'NME6',
#   'NME7',
#   'POLR2I',
#   'PNPT1',
#   'UPRT',
#   'RRM2',
#   'NME3',
#   'POLD4',
#   'POLR1B',
#   'ITPA',
#   'POLR3F',
#   'DPYD',
#   'POLE2',
#   'TK1'],
#  'KEGG_PYRUVATE_METABOLISM': ['ACSS2',
#   'PC',
#   'PDHB',
#   'MDH1',
#   'ALDH9A1',
#   'GRHPR'],
#  'KEGG_REGULATION_OF_ACTIN_CYTOSKELETON': ['CRK',
#   'PAK2',
#   'PIK3CG',
#   'PXN',
#   'ARAF',
#   'MYL12A',
#   'ITGAM',
#   'CYFIP2',
#   'PDGFD',
#   'SSH2',
#   'LIMK2',
#   'ITGB5',
#   'PPP1CA',
#   'RHOA',
#   'FGF9',
#   'MAPK1',
#   'PFN1',
#   'IQGAP1',
#   'DIAPH2',
#   'ITGA3',
#   'MAPK3',
#   'PIP5K1A',
#   'SLC9A1',
#   'MSN',
#   'MYL9',
#   'ITGB4',
#   'PIP4K2C',
#   'ARHGEF7',
#   'GIT1'],
#  'KEGG_RENAL_CELL_CARCINOMA': ['GRB2',
#   'MAP2K1',
#   'PAK4',
#   'TCEB1',
#   'FH',
#   'PGF',
#   'RAP1A',
#   'AKT2',
#   'EPAS1',
#   'ARAF',
#   'MAPK3',
#   'PAK2'],
#  'KEGG_RIBOSOME': ['RPS9',
#   'RPS7',
#   'RPL13A',
#   'RPL32',
#   'UBA52',
#   'RPS15',
#   'RSL24D1',
#   'RPS4X',
#   'RPS3',
#   'RPS29',
#   'RPS16',
#   'RPS5',
#   'RPS12',
#   'RPL35A',
#   'RPL37A',
#   'RPL5'],
#  'KEGG_RIG_I_LIKE_RECEPTOR_SIGNALING_PATHWAY': ['TRAF3',
#   'RELA',
#   'NFKBIA',
#   'IKBKE',
#   'IL8',
#   'IRF7',
#   'MAPK13',
#   'AZI2',
#   'DAK',
#   'MAPK14'],
#  'KEGG_RNA_DEGRADATION': ['ENO2',
#   'XRN1',
#   'LSM4',
#   'DIS3',
#   'EXOSC2',
#   'CNOT3',
#   'LSM3',
#   'LSM5',
#   'NAA38',
#   'MPHOSPH6',
#   'PARN'],
#  'KEGG_SMALL_CELL_LUNG_CANCER': ['ITGA3',
#   'CYCS',
#   'PIAS4',
#   'BCL2',
#   'PIK3CB',
#   'TRAF4',
#   'E2F3',
#   'TP53',
#   'LAMC3',
#   'AKT1',
#   'TRAF6',
#   'MAX',
#   'PIK3CG'],
#  'KEGG_SNARE_INTERACTIONS_IN_VESICULAR_TRANSPORT': ['STX17',
#   'STX1B',
#   'VAMP2',
#   'VAMP4',
#   'STX12',
#   'STX4'],
#  'KEGG_SPHINGOLIPID_METABOLISM': ['NEU1',
#   'SGPP1',
#   'ARSA',
#   'CERK',
#   'B4GALT6',
#   'SMPD3'],
#  'KEGG_SPLICEOSOME': ['HNRNPC',
#   'HNRNPK',
#   'ISY1',
#   'HSPA1A',
#   'SRSF6',
#   'HNRNPA3',
#   'DDX42',
#   'RBMX',
#   'SRSF5',
#   'NCBP2',
#   'LSM6',
#   'PRPF8',
#   'SYF2',
#   'PRPF4',
#   'SRSF2',
#   'HSPA6',
#   'PRPF3',
#   'THOC2',
#   'SF3B5',
#   'PRPF19',
#   'SNRPB2',
#   'MAGOHB',
#   'SRSF1',
#   'SNRPF'],
#  'KEGG_SYSTEMIC_LUPUS_ERYTHEMATOSUS': ['FCGR2A',
#   'HLA-DQB1',
#   'HIST1H2AG',
#   'H2AFX',
#   'HIST1H2AC',
#   'TROVE2',
#   'SNRPB',
#   'HLA-DMA',
#   'HLA-DPA1',
#   'H2AFZ',
#   'HLA-DOB'],
#  'KEGG_TGF_BETA_SIGNALING_PATHWAY': ['SKP1',
#   'CDKN2B',
#   'THBS2',
#   'TGFB3',
#   'RHOA',
#   'TGFBR2',
#   'BMP8B',
#   'SMAD2',
#   'RBL2',
#   'PPP2CB',
#   'THBS4'],
#  'KEGG_TIGHT_JUNCTION': ['PARD6G',
#   'INADL',
#   'SRC',
#   'MLLT4',
#   'JAM2',
#   'GNAI2',
#   'ACTG1',
#   'MYL5',
#   'GNAI3',
#   'AKT3',
#   'PPP2R1B',
#   'RAB13',
#   'PARD6B',
#   'MYL9',
#   'PPP2CB',
#   'MYL12B',
#   'PPP2CA'],
#  'KEGG_TOLL_LIKE_RECEPTOR_SIGNALING_PATHWAY': ['TAB2',
#   'MAPK9',
#   'TLR4',
#   'RIPK1',
#   'PIK3CG',
#   'TRAF3',
#   'NFKB1',
#   'TRAF6',
#   'TIRAP',
#   'CD86',
#   'LY9',
#   'TLR8',
#   'MAPK11',
#   'MAP3K7',
#   'MYD88'],
#  'KEGG_TYPE_II_DIABETES_MELLITUS': ['MAPK9',
#   'PIK3R5',
#   'PIK3R3',
#   'MTOR',
#   'PIK3CB'],
#  'KEGG_TYPE_I_DIABETES_MELLITUS': ['HLA-DQA2',
#   'GZMB',
#   'HSPD1',
#   'IFNG',
#   'PTPRN',
#   'CD28'],
#  'KEGG_T_CELL_RECEPTOR_SIGNALING_PATHWAY': ['HRAS',
#   'PIK3R1',
#   'NFAT5',
#   'CD28',
#   'PPP3CB',
#   'MAPK11',
#   'CD8B',
#   'PPP3R1',
#   'NFKBIA',
#   'CD8A',
#   'VAV1',
#   'PIK3CG',
#   'CD3E',
#   'NRAS',
#   'NFATC1',
#   'CD4',
#   'MAPK9',
#   'IFNG',
#   'MALT1'],
#  'KEGG_UBIQUITIN_MEDIATED_PROTEOLYSIS': ['UBE2Q2',
#   'DDB1',
#   'UBE2F',
#   'UBA3',
#   'FBXO4',
#   'PIAS1',
#   'UBE2E1',
#   'HERC3',
#   'UBE2L6',
#   'STUB1',
#   'ANAPC2',
#   'WWP2',
#   'FZR1',
#   'PIAS4',
#   'ANAPC10',
#   'XIAP',
#   'CUL1',
#   'UBE2K',
#   'SKP1',
#   'CBL',
#   'UBE2D1',
#   'TRIM32',
#   'HERC4',
#   'BRCA1',
#   'TCEB2'],
#  'KEGG_VALINE_LEUCINE_AND_ISOLEUCINE_DEGRADATION': ['BCAT2',
#   'DBT',
#   'ALDH3A2',
#   'HIBADH',
#   'ACAA1',
#   'ACADSB',
#   'MCCC2',
#   'BCKDHB'],
#  'KEGG_VASCULAR_SMOOTH_MUSCLE_CONTRACTION': ['PPP1CC',
#   'PPP1CA',
#   'ADCY3',
#   'CALM3',
#   'MYL6B',
#   'ADCY4',
#   'GNAQ',
#   'ITPR1',
#   'PLA2G6',
#   'MYH11',
#   'KCNMB1',
#   'GUCY1B3',
#   'MAPK3'],
#  'KEGG_VASOPRESSIN_REGULATED_WATER_REABSORPTION': ['PRKACB',
#   'VAMP2',
#   'STX4',
#   'RAB5A',
#   'CREB5',
#   'DCTN4',
#   'CREB3L4'],
#  'KEGG_VEGF_SIGNALING_PATHWAY': ['CDC42',
#   'PLCG2',
#   'PRKCB',
#   'NFATC1',
#   'NRAS',
#   'KRAS',
#   'AKT2',
#   'CASP9',
#   'RAC3',
#   'HSPB1',
#   'NFATC3'],
#  'KEGG_VIBRIO_CHOLERAE_INFECTION': ['PRKX',
#   'ATP6V1E1',
#   'PLCG2',
#   'ATP6V1G1',
#   'SLC12A2',
#   'SEC61B',
#   'TJP2',
#   'ATP6V0E2'],
#  'KEGG_VIRAL_MYOCARDITIS': ['MYH3',
#   'HLA-A',
#   'ITGB2',
#   'EIF4G1',
#   'HLA-DQA2',
#   'MYH9',
#   'HLA-F',
#   'ACTG1',
#   'ABL2',
#   'FYN'],
#  'KEGG_WNT_SIGNALING_PATHWAY': ['PPP2R5A',
#   'NKD1',
#   'EP300',
#   'DVL1',
#   'NFATC1',
#   'PRKCA',
#   'CUL1',
#   'PPP2CB',
#   'TCF7',
#   'CSNK1A1',
#   'CSNK1A1L',
#   'PRKACA',
#   'CACYBP',
#   'MAP3K7',
#   'PRKX',
#   'TP53',
#   'FRAT2',
#   'RHOA',
#   'FZD2',
#   'RBX1',
#   'PORCN'],
#  'MIPS_17S_U2_SNRNP': ['SF3A3', 'SNRPA1', 'U2AF2', 'DHX15', 'SF3B1', 'SF3B2'],
#  'MIPS_28S_RIBOSOMAL_SUBUNIT_MITOCHONDRIAL': ['MRPS7',
#   'MRPS18A',
#   'MRPS22',
#   'MRPS33',
#   'MRPS30'],
#  'MIPS_39S_RIBOSOMAL_SUBUNIT_MITOCHONDRIAL': ['MRPL3',
#   'MRPL21',
#   'MRPL52',
#   'MRPL48',
#   'MRPL9',
#   'MRPL33',
#   'MRPL47',
#   'MRPL36'],
#  'MIPS_40S_RIBOSOMAL_SUBUNIT_CYTOPLASMIC': ['RPS10',
#   'RPS25',
#   'RPS16',
#   'RPS9',
#   'RPS23',
#   'RPS4X'],
#  'MIPS_55S_RIBOSOME_MITOCHONDRIAL': ['MRPL17',
#   'MRPS18A',
#   'MRPL20',
#   'MRPS11',
#   'MRPL37',
#   'MRPL24',
#   'MRPL1',
#   'MRPL32',
#   'MRPL2',
#   'MRPL27',
#   'MRPL50',
#   'MRPL28',
#   'MRPS35',
#   'MRPS36'],
#  'MIPS_60S_RIBOSOMAL_SUBUNIT_CYTOPLASMIC': ['RPL38',
#   'RPL6',
#   'RPL3',
#   'RPL26',
#   'RPL18',
#   'RPL27',
#   'RPL10A',
#   'RPL31',
#   'RPL41'],
#  'MIPS_CEN_COMPLEX': ['RING1', 'CENPO', 'KIF23', 'RNF2', 'SUPT16H', 'SRRT'],
#  'MIPS_C_COMPLEX_SPLICEOSOME': ['SNRNP200',
#   'PRPF19',
#   'HNRNPR',
#   'SKIV2L2',
#   'SF3B2',
#   'HNRNPU',
#   'SNW1',
#   'PPWD1',
#   'GPATCH1',
#   'CWC27',
#   'SYF2',
#   'TFIP11',
#   'MAGOH',
#   'EIF4A3',
#   'LSM3'],
#  'MIPS_MEDIATOR_COMPLEX': ['MED13',
#   'MED23',
#   'MED28',
#   'MED25',
#   'CDK8',
#   'MED16'],
#  'MIPS_NOP56P_ASSOCIATED_PRE_RRNA_COMPLEX': ['RPL14',
#   'RPS18',
#   'RPL27A',
#   'RPL6',
#   'RPL28',
#   'GNL3',
#   'RPS14',
#   'FBL',
#   'RPL4',
#   'RPL8',
#   'TOP1',
#   'TUBA1A',
#   'RPL36A',
#   'RPL13A',
#   'DHX9',
#   'RBM28',
#   'RPL13',
#   'RPS29',
#   'RPL36'],
#  'MIPS_PA700_20S_PA28_COMPLEX': ['PSMD11',
#   'PSMC3',
#   'PSMD10',
#   'PSMB2',
#   'PSMB4',
#   'PSMD14',
#   'PSMA1'],
#  'MIPS_RIBOSOME_CYTOPLASMIC': ['RPL10',
#   'RPL8',
#   'RPL11',
#   'RPL6',
#   'RPL36A',
#   'RPS21',
#   'RPLP2',
#   'RPS27A',
#   'FAU',
#   'RPS18',
#   'RPS9',
#   'RPL24',
#   'RPL22',
#   'RPS24',
#   'RPS28'],
#  'MIPS_SPLICEOSOME': ['LSM7',
#   'SMU1',
#   'SNRNP40',
#   'DHX15',
#   'SRRM2',
#   'SRSF7',
#   'SNRPD2',
#   'PPM1G',
#   'WBP11',
#   'CDC5L',
#   'TXNL4A',
#   'THOC7',
#   'SLU7',
#   'NUDT21',
#   'SRSF3',
#   'C19orf43',
#   'RBM8A',
#   'IK',
#   'SF3B3',
#   'SNRNP70',
#   'SNRPE',
#   'CTNNBL1',
#   'SART1',
#   'XAB2',
#   'MOV10',
#   'NHP2L1',
#   'LSM4'],
#  'PID_A6B1_A6B4_INTEGRIN_PATHWAY': ['ITGB1',
#   'PIK3CA',
#   'PIK3R1',
#   'AKT1',
#   'PRKCA',
#   'YWHAZ'],
#  'PID_AJDISS_2PATHWAY': ['CTNNB1',
#   'ADAM10',
#   'CASP3',
#   'CABLES1',
#   'CDH1',
#   'SRC'],
#  'PID_AMB2_NEUTROPHILS_PATHWAY': ['LRP1',
#   'AGER',
#   'PRKCZ',
#   'PLAU',
#   'RAP1A',
#   'LCK'],
#  'PID_ANGIOPOIETINRECEPTOR_PATHWAY': ['GRB2',
#   'PIK3CA',
#   'SHC1',
#   'MAPK14',
#   'STAT5B',
#   'ETS1',
#   'RELA',
#   'STAT5A'],
#  'PID_AP1_PATHWAY': ['ATF2',
#   'HLA-A',
#   'FOSL2',
#   'EGR1',
#   'HIF1A',
#   'TP53',
#   'DMTF1',
#   'CTNNB1',
#   'GATA2'],
#  'PID_ARF6_TRAFFICKINGPATHWAY': ['CTNND1',
#   'ITGA9',
#   'SCAMP2',
#   'PLD1',
#   'EXOC4',
#   'EXOC2',
#   'ASAP2'],
#  'PID_AR_NONGENOMIC_PATHWAY': ['GNB1', 'MAPK1', 'CREB1', 'MAPK3', 'PELP1'],
#  'PID_AR_PATHWAY': ['AKT1',
#   'UBA3',
#   'PELP1',
#   'RANBP9',
#   'NCOA2',
#   'HNRNPA1',
#   'SVIL',
#   'SRF',
#   'XRCC5',
#   'TGFB1I1'],
#  'PID_AR_TF_PATHWAY': ['SMARCC1',
#   'RXRB',
#   'RCHY1',
#   'DNAJA1',
#   'MDM2',
#   'CREBBP',
#   'SENP1',
#   'PDE9A'],
#  'PID_ATF2_PATHWAY': ['POU2F1',
#   'MAPK14',
#   'RUVBL2',
#   'MAPK8',
#   'SOCS3',
#   'IL23A',
#   'JDP2',
#   'DUSP5',
#   'GADD45A'],
#  'PID_ATM_PATHWAY': ['FAM175A', 'RBBP8', 'MRE11A', 'MDM2', 'KAT5', 'XRCC4'],
#  'PID_ATR_PATHWAY': ['CCNA2',
#   'RAD17',
#   'CHEK1',
#   'TIMELESS',
#   'FANCD2',
#   'FBXW11',
#   'HUS1'],
#  'PID_AURORA_A_PATHWAY': ['AURKA', 'CDC25B', 'AURKAIP1', 'OAZ1', 'TACC1'],
#  'PID_AURORA_B_PATHWAY': ['NCL', 'AURKB', 'PPP1CC', 'AURKA', 'NDC80', 'SMC2'],
#  'PID_AVB3_INTEGRIN_PATHWAY': ['CBL',
#   'TLN1',
#   'MFGE8',
#   'VCL',
#   'SRC',
#   'COL9A3',
#   'AKT1',
#   'IRS1',
#   'COL8A2'],
#  'PID_AVB3_OPN_PATHWAY': ['CD44', 'CDC42', 'MAPK1', 'RAC1', 'PIK3R1'],
#  'PID_BCR_5PATHWAY': ['NFKBIB',
#   'IKBKB',
#   'CARD11',
#   'JUN',
#   'SOS1',
#   'VAV2',
#   'CD79A',
#   'AKT1',
#   'BLNK',
#   'MAP4K1',
#   'CSK',
#   'RASA1',
#   'DOK1'],
#  'PID_BETACATENIN_NUC_PATHWAY': ['ID2',
#   'KLF4',
#   'TLE4',
#   'NCOA2',
#   'RUVBL2',
#   'CTNNB1',
#   'TNIK',
#   'EP300',
#   'CBY1',
#   'CTNNBIP1',
#   'TLE2'],
#  'PID_BMPPATHWAY': ['SMAD1', 'XIAP', 'CTDSP1', 'CTDSPL', 'RGMB'],
#  'PID_CASPASE_PATHWAY': ['LMNB1',
#   'CASP6',
#   'CASP9',
#   'BCL2',
#   'PTK2',
#   'BIRC3',
#   'BIRC2',
#   'CFL2',
#   'BID'],
#  'PID_CD8TCRDOWNSTREAMPATHWAY': ['MAPK8',
#   'IL2RA',
#   'IL2RG',
#   'B2M',
#   'RAF1',
#   'MAPK3',
#   'ELK1',
#   'CD3G',
#   'IFNAR1',
#   'PPP3CB'],
#  'PID_CD8TCRPATHWAY': ['LCK',
#   'LAT',
#   'CHUK',
#   'ZAP70',
#   'CARD11',
#   'MAP3K14',
#   'IKBKG',
#   'FYN',
#   'CD86',
#   'AKT1'],
#  'PID_CDC42_PATHWAY': ['PAK2',
#   'MAPK9',
#   'ARHGEF7',
#   'DLG1',
#   'CBL',
#   'BRAF',
#   'SRC',
#   'TIAM1',
#   'YES1',
#   'RPS6KB1',
#   'TNK2',
#   'HRAS'],
#  'PID_CERAMIDE_PATHWAY': ['MAPK3',
#   'MYC',
#   'SMPD3',
#   'MAP2K1',
#   'TRADD',
#   'SPHK2',
#   'MAP2K4',
#   'PRKRA',
#   'MAPK1'],
#  'PID_CMYB_PATHWAY': ['TAB1',
#   'NLK',
#   'HSPA8',
#   'CCND1',
#   'HRAS',
#   'ZFPM1',
#   'PTGS2',
#   'GATA1',
#   'GATA3',
#   'CLTA',
#   'CSF1R',
#   'CREBBP',
#   'SMARCA2',
#   'MAF'],
#  'PID_CXCR3PATHWAY': ['CXCR3',
#   'DNM1',
#   'PDPK1',
#   'MAPK3',
#   'NRAS',
#   'MAP2K1',
#   'KRAS'],
#  'PID_CXCR4_PATHWAY': ['GNAZ',
#   'PXN',
#   'ARRB2',
#   'CFL1',
#   'ADRBK1',
#   'CDC42',
#   'RHOA',
#   'CD4',
#   'PIK3R1',
#   'PLCB2',
#   'GNAO1',
#   'RALB',
#   'JAK2',
#   'LYN',
#   'ITGAV',
#   'PTK2B',
#   'RAC1',
#   'LIMK1'],
#  'PID_DELTANP63PATHWAY': ['ADA',
#   'CCNB2',
#   'ITCH',
#   'TCF7L1',
#   'STXBP4',
#   'WWP1',
#   'HELLS'],
#  'PID_E2F_PATHWAY': ['TRRAP',
#   'CDC6',
#   'RANBP1',
#   'XRCC1',
#   'E2F6',
#   'TFDP1',
#   'TOPBP1',
#   'PRMT5',
#   'TYMS',
#   'CCNE1',
#   'YY1',
#   'KAT2B',
#   'UXT'],
#  'PID_ECADHERIN_NASCENTAJ_PATHWAY': ['CTNND1',
#   'CSNK2B',
#   'DLG1',
#   'ABI1',
#   'NME1',
#   'CYFIP2',
#   'RAP1A'],
#  'PID_ECADHERIN_STABILIZATION_PATHWAY': ['PLEKHA7',
#   'MYO6',
#   'VASP',
#   'LIMA1',
#   'MLLT4',
#   'NCK1',
#   'CYFIP2'],
#  'PID_ENDOTHELINPATHWAY': ['GNAI3',
#   'GNAI2',
#   'MAP2K2',
#   'RHOA',
#   'ADCY3',
#   'JUN',
#   'GNA11',
#   'PRKCB',
#   'GNA12'],
#  'PID_EPHBFWDPATHWAY': ['EPHB4', 'MAP2K1', 'PIK3R1', 'RASA1', 'RAC1', 'SRC'],
#  'PID_EPOPATHWAY': ['EPOR', 'SHC1', 'MAPK8', 'CRKL', 'IRS2', 'MAPK14'],
#  'PID_ERA_GENOMIC_PATHWAY': ['SOD1',
#   'EBAG9',
#   'KLRC3',
#   'SAFB',
#   'BRCA1',
#   'NCOA7',
#   'ESR2',
#   'MPG',
#   'NCOA2',
#   'SET'],
#  'PID_ERBB1_DOWNSTREAM_PATHWAY': ['BCL2L1',
#   'PPP2R1A',
#   'SOS1',
#   'PIK3R1',
#   'MLST8',
#   'PRKCZ',
#   'SMAD1',
#   'PRKCD',
#   'MAP2K1',
#   'ARPC5',
#   'NRAS',
#   'KSR1',
#   'GRB2',
#   'SLC9A1',
#   'RAB5A',
#   'MEF2C',
#   'PLD1',
#   'RICTOR',
#   'WASL'],
#  'PID_ERBB1_INTERNALIZATION_PATHWAY': ['SRC',
#   'GRB2',
#   'SYNJ1',
#   'PIK3CB',
#   'PIK3R3',
#   'CDC42',
#   'DNM1'],
#  'PID_ERBB1_RECEPTOR_PROXIMAL_PATHWAY': ['GNAI1',
#   'SRC',
#   'PIK3CD',
#   'WASL',
#   'GSN',
#   'STAT3'],
#  'PID_ERBB2ERBB3PATHWAY': ['PTPN11',
#   'RAC1',
#   'PIK3CA',
#   'PPP3CB',
#   'AKT1',
#   'NRAS',
#   'MTOR'],
#  'PID_ERBB4_PATHWAY': ['NRG1', 'ADAM17', 'DLG4', 'PIK3R3', 'WWOX'],
#  'PID_ER_NONGENOMIC_PATHWAY': ['GNB1',
#   'SHC1',
#   'GNAO1',
#   'GNA13',
#   'GNAL',
#   'PIK3R1',
#   'HRAS'],
#  'PID_FAK_PATHWAY': ['RAP1A',
#   'RRAS',
#   'KLF8',
#   'NCK1',
#   'CRK',
#   'ITGA5',
#   'ARHGEF11',
#   'FYN',
#   'MAPK8IP3',
#   'NCK2'],
#  'PID_FANCONI_PATHWAY': ['XRCC3',
#   'CHEK1',
#   'RAD50',
#   'FANCE',
#   'RPA1',
#   'FANCF',
#   'FANCI',
#   'FANCM'],
#  'PID_FASPATHWAY': ['CASP8',
#   'BIRC2',
#   'FASLG',
#   'SMPD1',
#   'PDPK1',
#   'RFC1',
#   'BID'],
#  'PID_FCER1PATHWAY': ['CHUK',
#   'FYN',
#   'PXN',
#   'SOS1',
#   'MAPK8',
#   'RASA1',
#   'FCER1G',
#   'LCP2',
#   'PTPN13',
#   'ITK',
#   'FCGR2B'],
#  'PID_FGF_PATHWAY': ['PTK2B',
#   'CDH1',
#   'STAT1',
#   'CTNND1',
#   'RUNX2',
#   'SRC',
#   'CTTN',
#   'FGFR4'],
#  'PID_FOXM1PATHWAY': ['CKS1B', 'EP300', 'TGFA', 'CENPB', 'GSK3A', 'CCNE1'],
#  'PID_FOXOPATHWAY': ['USP7',
#   'RAN',
#   'YWHAE',
#   'CAT',
#   'MST1',
#   'KAT2B',
#   'FASLG',
#   'MAPK8',
#   'GADD45A'],
#  'PID_FRA_PATHWAY': ['NFATC3', 'TXLNG', 'DMTF1', 'HMOX1', 'MMP9'],
#  'PID_GMCSF_PATHWAY': ['PIM1', 'HRAS', 'STAT1', 'JAK2', 'CISH', 'PTPN11'],
#  'PID_HDAC_CLASSII_PATHWAY': ['YWHAE',
#   'TUBA1B',
#   'BCL6',
#   'HDAC10',
#   'YWHAB',
#   'MEF2C'],
#  'PID_HDAC_CLASSI_PATHWAY': ['HDAC5',
#   'PRKACA',
#   'SAP30',
#   'HDAC3',
#   'SUMO1',
#   'SMURF1',
#   'GATAD2A',
#   'HDAC1',
#   'HDAC11',
#   'PRMT5',
#   'NCOR2',
#   'STAT3'],
#  'PID_HEDGEHOG_GLIPATHWAY': ['IFT172',
#   'HDAC2',
#   'SAP18',
#   'KIF3A',
#   'MTSS1',
#   'ARRB2',
#   'RBBP7',
#   'PTCH1'],
#  'PID_HES_HEYPATHWAY': ['TCF3',
#   'RUNX2',
#   'RBBP8',
#   'STAT3',
#   'PARP1',
#   'GAA',
#   'HDAC1'],
#  'PID_HIF1_TFPATHWAY': ['PFKL',
#   'NCOA1',
#   'SLC2A1',
#   'BHLHE40',
#   'PLIN2',
#   'ARNT',
#   'NDRG1',
#   'HDAC7',
#   'CXCR4',
#   'NPM1'],
#  'PID_HIF2PATHWAY': ['CITED2', 'SLC2A1', 'TCEB2', 'MMP14', 'VHL'],
#  'PID_HIVNEFPATHWAY': ['CHUK',
#   'BAG4',
#   'TRAF1',
#   'CASP9',
#   'CASP3',
#   'DAXX',
#   'MAP3K14'],
#  'PID_IFNGPATHWAY': ['AKT1',
#   'DAPK1',
#   'RAP1B',
#   'IFNG',
#   'PTGES2',
#   'MAP3K11',
#   'MAPK3'],
#  'PID_IL12_2PATHWAY': ['NFKB1',
#   'IL1R1',
#   'GZMA',
#   'IL12RB2',
#   'HLX',
#   'STAT4',
#   'HLA-A',
#   'IL2RB',
#   'SOCS1',
#   'PPP3CB',
#   'GADD45B'],
#  'PID_IL12_STAT4PATHWAY': ['CD3D', 'HLA-DRB1', 'PIAS2', 'CD28', 'HLA-DRA'],
#  'PID_IL1PATHWAY': ['RELA', 'IRAK4', 'IL1RAP', 'IL1RN', 'CHUK', 'TAB1'],
#  'PID_IL23PATHWAY': ['CD3E', 'STAT3', 'NFKB1', 'ITGA3', 'RELA'],
#  'PID_IL2_1PATHWAY': ['PPP2R5D',
#   'RAF1',
#   'FOS',
#   'BCL2',
#   'MYC',
#   'CISH',
#   'PTK2B',
#   'MAPK8',
#   'RHOA',
#   'PTPN11'],
#  'PID_IL2_PI3KPATHWAY': ['SOS1', 'JAK1', 'BCL2L1', 'MTOR', 'FOXO3', 'RELA'],
#  'PID_IL4_2PATHWAY': ['JAK1',
#   'STAT6',
#   'EGR2',
#   'IRS2',
#   'IRS1',
#   'PIK3R1',
#   'SP1',
#   'IRF4',
#   'INPP5D'],
#  'PID_IL6_7PATHWAY': ['SOS1',
#   'SOCS3',
#   'PRKCD',
#   'PIAS3',
#   'RAC1',
#   'JUN',
#   'JAK1',
#   'PTPRE'],
#  'PID_IL8CXCR2_PATHWAY': ['GNB1', 'CXCR2', 'VASP', 'GNG2', 'PLD2', 'IL8'],
#  'PID_ILK_PATHWAY': ['CREB1',
#   'PXN',
#   'ELMO2',
#   'AURKA',
#   'SNAI1',
#   'TNS1',
#   'DIAPH1',
#   'PARVB'],
#  'PID_INSULIN_PATHWAY': ['EXOC1',
#   'RPS6KB1',
#   'CBL',
#   'PDPK1',
#   'AKT1',
#   'CRK',
#   'RHOQ',
#   'FOXO3'],
#  'PID_INTEGRIN1_PATHWAY': ['LAMA2',
#   'ITGAV',
#   'ITGA5',
#   'COL6A3',
#   'COL6A1',
#   'IGSF8',
#   'LAMB3'],
#  'PID_INTEGRIN3_PATHWAY': ['PLAU', 'TGFBI', 'PDGFRB', 'PLAUR'],
#  'PID_INTEGRIN_A4B1_PATHWAY': ['PXN', 'SRC', 'PTPRA', 'YWHAZ', 'MDK'],
#  'PID_KITPATHWAY': ['VAV1',
#   'TEC',
#   'PIK3C2B',
#   'GRAP2',
#   'MAP2K1',
#   'FOXO3',
#   'FER',
#   'CREBBP',
#   'PDPK1'],
#  'PID_LKB1_PATHWAY': ['SMAD4',
#   'TSC1',
#   'PRKACA',
#   'MARK4',
#   'MLST8',
#   'RPTOR',
#   'MARK2'],
#  'PID_LYSOPHOSPHOLIPID_PATHWAY': ['GAB1',
#   'PTK2',
#   'PIK3R1',
#   'LYN',
#   'RAC1',
#   'GNA15',
#   'RELA',
#   'TIAM1',
#   'MAPT',
#   'ARHGEF1'],
#  'PID_MAPKTRKPATHWAY': ['HRAS', 'MAP2K3', 'MEF2C', 'CDK5', 'MAP2K5', 'NRAS'],
#  'PID_MET_PATHWAY': ['PRKCI',
#   'MAPK8',
#   'HGF',
#   'RANBP10',
#   'HRAS',
#   'PTK2',
#   'EGR1',
#   'PIK3CA',
#   'RHOA',
#   'CTNNB1',
#   'WASL',
#   'SOS1',
#   'RAP1B',
#   'PARD6A',
#   'RPTOR'],
#  'PID_MTOR_4PATHWAY': ['ULK2',
#   'KRAS',
#   'BNIP3',
#   'EIF4B',
#   'RICTOR',
#   'EEF2K',
#   'BRAF',
#   'ATG13',
#   'DDIT4',
#   'RRAGD',
#   'RRAGC',
#   'PRKCA',
#   'IRS1'],
#  'PID_MYC_ACTIVPATHWAY': ['BMI1',
#   'SUPT3H',
#   'CCND2',
#   'CREBBP',
#   'ODC1',
#   'KAT5',
#   'PMAIP1',
#   'GAPDH',
#   'BAX',
#   'SLC2A1',
#   'EIF4A1',
#   'UBTF',
#   'SERPINI1',
#   'POLR3D'],
#  'PID_MYC_REPRESSPATHWAY': ['CSDE1',
#   'MAX',
#   'HDAC1',
#   'MXD4',
#   'NDRG2',
#   'ZFP36L1',
#   'BCL2',
#   'BRCA1',
#   'ZBTB17',
#   'CCL5'],
#  'PID_NFAT_3PATHWAY': ['MAPK9',
#   'CASP3',
#   'PPP3R1',
#   'BAX',
#   'NR4A1',
#   'PRKCH',
#   'NFATC1',
#   'BCL2L1',
#   'MAPK14',
#   'MAP3K1'],
#  'PID_NFAT_TFPATHWAY': ['NFATC1',
#   'IL8',
#   'NFATC3',
#   'JUNB',
#   'PTPRK',
#   'PTPN1',
#   'FASLG'],
#  'PID_NOTCH_PATHWAY': ['NCSTN',
#   'NOTCH2',
#   'ITCH',
#   'FBXW7',
#   'FURIN',
#   'JAG1',
#   'PSENEN',
#   'CBL',
#   'PTCRA'],
#  'PID_P38ALPHABETADOWNSTREAMPATHWAY': ['PLA2G4A',
#   'EIF4E',
#   'MITF',
#   'CREB1',
#   'ELK4',
#   'ATF6'],
#  'PID_P53DOWNSTREAMPATHWAY': ['SMARCA4',
#   'NFYA',
#   'PRMT1',
#   'PYCARD',
#   'ATF3',
#   'CCNK',
#   'TP53',
#   'STEAP3',
#   'JUN',
#   'MLH1',
#   'ZNF385A',
#   'HTT',
#   'CSE1L',
#   'SERPINE1',
#   'SH2D1A',
#   'PLK3',
#   'CREBBP',
#   'PERP',
#   'NFYC',
#   'CCNG1',
#   'BCL6',
#   'VDR',
#   'RB1'],
#  'PID_P53REGULATIONPATHWAY': ['TRIM28',
#   'PIN1',
#   'CCNA2',
#   'RPL11',
#   'HUWE1',
#   'PPP1R13L',
#   'PRMT5',
#   'USP7',
#   'CREBBP',
#   'PPM1D',
#   'CHEK1'],
#  'PID_P73PATHWAY': ['FASN',
#   'CCNA2',
#   'BAX',
#   'UBE4B',
#   'PML',
#   'BRCA2',
#   'TUBA1A',
#   'TP53I3',
#   'RAD51',
#   'PPAP2A',
#   'MDM2',
#   'SP1',
#   'RNF43'],
#  'PID_P75NTRPATHWAY': ['OMG',
#   'FURIN',
#   'MAGED1',
#   'MAPK9',
#   'PRKCZ',
#   'NGFRAP1',
#   'BIRC3',
#   'CASP9',
#   'IKBKG',
#   'BIRC2',
#   'NCSTN'],
#  'PID_PDGFRBPATHWAY': ['RAC1',
#   'GRB2',
#   'ABI1',
#   'PDGFB',
#   'WASF2',
#   'RASA1',
#   'SRF',
#   'PRKCE',
#   'LYN',
#   'PTPN2',
#   'PLCG1',
#   'PTEN',
#   'ARPC1B',
#   'ABL1',
#   'PRKCD',
#   'PIN1',
#   'ARPC4',
#   'RHOA',
#   'PTPN11',
#   'ACTR3',
#   'ARHGDIA',
#   'STAT3',
#   'BLK',
#   'ACTN4'],
#  'PID_PI3KCIAKTPATHWAY': ['CASP9', 'AKT3', 'YWHAQ', 'TBC1D4', 'SRC', 'FOXO3'],
#  'PID_PI3KCIPATHWAY': ['SYK',
#   'ITK',
#   'LCK',
#   'PTEN',
#   'PLCG2',
#   'PIK3CG',
#   'FOXO3',
#   'INPPL1',
#   'PLCG1'],
#  'PID_PI3KPLCTRKPATHWAY': ['YWHAQ',
#   'PIK3R1',
#   'GRB2',
#   'SOS1',
#   'FOXO3',
#   'STAT5A'],
#  'PID_PLK1_PATHWAY': ['CLSPN',
#   'FBXW11',
#   'GORASP1',
#   'PPP1R12A',
#   'ECT2',
#   'FZR1',
#   'CDK1',
#   'CDC20'],
#  'PID_PS1PATHWAY': ['NKD1',
#   'APH1B',
#   'NLK',
#   'NCSTN',
#   'CTBP1',
#   'NOTCH1',
#   'HDAC1',
#   'CREBBP'],
#  'PID_PTP1BPATHWAY': ['DOK1',
#   'ITGA2B',
#   'LAT',
#   'FGR',
#   'GRB2',
#   'SHC1',
#   'CSF1',
#   'TYK2'],
#  'PID_RAC1_PATHWAY': ['ARPC5',
#   'STAT3',
#   'NOXA1',
#   'NCF1',
#   'ARHGAP5',
#   'RAC1',
#   'MAP3K11',
#   'MAP2K3',
#   'CFL1'],
#  'PID_RAC1_REG_PATHWAY': ['RALBP1',
#   'SOS1',
#   'ARHGEF7',
#   'DOCK2',
#   'DEF6',
#   'ELMO1'],
#  'PID_RB_1PATHWAY': ['CTBP1',
#   'ATF2',
#   'SIRT1',
#   'E2F1',
#   'CBX4',
#   'CCNE1',
#   'E2F2',
#   'PPP2CA',
#   'CCNA2',
#   'RAF1'],
#  'PID_REG_GR_PATHWAY': ['SPI1',
# ...
#  'REACTOME_RNA_POL_I_RNA_POL_III_AND_MITOCHONDRIAL_TRANSCRIPTION': ['KAT2B',
#   'HIST4H4',
#   'HIST1H2BN',
#   'HIST1H2BC',
#   'GTF3C4',
#   'GTF2H3',
#   'SNAPC4',
#   'SNAPC2',
#   'POLR2H',
#   'TFB2M',
#   'POLR3C',
#   'POU2F1',
#   'SSB'],
#  'REACTOME_RNA_POL_I_TRANSCRIPTION': ['HIST1H2BC',
#   'H3F3B',
#   'POLR1B',
#   'HIST4H4',
#   'CDK7',
#   'ERCC6',
#   'POLR1C'],
#  'REACTOME_SCFSKP2_MEDIATED_DEGRADATION_OF_P27_P21': ['RPS27A',
#   'CCNA2',
#   'PSMB7',
#   'PSMC2',
#   'PSMD8',
#   'CDKN1A',
#   'PSMC4',
#   'PSMB1',
#   'PSME2',
#   'PSMD14'],
#  'REACTOME_SCF_BETA_TRCP_MEDIATED_DEGRADATION_OF_EMI1': ['SKP1',
#   'PSME1',
#   'PSMB1',
#   'PSMA3',
#   'RPS27A',
#   'PSMB6',
#   'PSMD8',
#   'PSMF1',
#   'PSMB7'],
#  'REACTOME_SEMAPHORIN_INTERACTIONS': ['LIMK1',
#   'FYN',
#   'CDC42',
#   'PTPRC',
#   'FES',
#   'PLXNC1',
#   'TYROBP',
#   'RAC1',
#   'HSP90AA1',
#   'MYH11'],
#  'REACTOME_SIGNALING_BY_EGFR_IN_CANCER': ['MTOR',
#   'PDPK1',
#   'MAPK1',
#   'RAF1',
#   'CSK',
#   'MAP2K1',
#   'RICTOR',
#   'PRKCE',
#   'CDK1',
#   'CASP9',
#   'CBL',
#   'MAPKAP1',
#   'PRKACA',
#   'AKT3',
#   'CHUK',
#   'ITPR3',
#   'PRKCA',
#   'HRAS',
#   'UBA52'],
#  'REACTOME_SIGNALING_BY_ERBB2': ['SRC',
#   'YES1',
#   'MAP2K1',
#   'RPS27A',
#   'ADCY4',
#   'RNF41',
#   'ITPR3',
#   'PRKCD',
#   'AKT3',
#   'CALM1',
#   'GSK3A',
#   'MAPKAP1',
#   'CREB1',
#   'TSC2',
#   'CASP9',
#   'THEM4'],
#  'REACTOME_SIGNALING_BY_ERBB4': ['FOXO4',
#   'NRAS',
#   'PSEN1',
#   'RICTOR',
#   'YWHAB',
#   'KRAS',
#   'SH2B1',
#   'PHLPP1',
#   'PSEN2',
#   'BTRC',
#   'NCSTN',
#   'NR4A1',
#   'CHUK',
#   'TAB2'],
#  'REACTOME_SIGNALING_BY_FGFR': ['YWHAB',
#   'ADRBK1',
#   'CALM2',
#   'MAP2K1',
#   'PHLPP1',
#   'CAMK4',
#   'CALM1',
#   'CASP9',
#   'PRKAR2A',
#   'PRKAR1A',
#   'MKNK1',
#   'AKT1S1',
#   'ADCY6',
#   'PRKCD',
#   'ITPR2',
#   'SPRY2'],
#  'REACTOME_SIGNALING_BY_FGFR_IN_DISEASE': ['PRKCD',
#   'PPP2CB',
#   'ADCY3',
#   'PIK3CA',
#   'MLST8',
#   'MAPK3',
#   'GRB2',
#   'FOXO3',
#   'TSC2',
#   'YWHAB',
#   'CALM3',
#   'ADCY4',
#   'AKT3',
#   'PIK3R1',
#   'ADRBK1',
#   'RPS6KB2',
#   'MKNK1',
#   'CHUK'],
#  'REACTOME_SIGNALING_BY_GPCR': ['ADCY6',
#   'C3AR1',
#   'CYSLTR1',
#   'FGD4',
#   'FGD1',
#   'FZD3',
#   'SOS1',
#   'TIAM1',
#   'LTB4R',
#   'PDE2A',
#   'GPBAR1',
#   'GIPR',
#   'P2RY10',
#   'RLN2',
#   'GNG5',
#   'FZD5',
#   'CDK1',
#   'HBEGF',
#   'PRKCQ',
#   'PLEKHG2',
#   'CXCL6',
#   'XCL2',
#   'PPP2R1B',
#   'IL8',
#   'AKT3',
#   'PTGIR',
#   'GNG7',
#   'CYSLTR2',
#   'EMR3',
#   'NTSR1',
#   'PTGER2',
#   'PRKCD',
#   'CCR10',
#   'P2RY12',
#   'CXCR4',
#   'RGS9',
#   'CCR2',
#   'CCL5',
#   'DGKD',
#   'ECT2',
#   'DGKQ',
#   'ADCY9',
#   'PIK3R3',
#   'F2RL1',
#   'VAV1',
#   'EMR2',
#   'GABBR1',
#   'C3',
#   'ABR',
#   'CALM2',
#   'PTAFR',
#   'PLCB1',
#   'PPP2CA',
#   'CXCL5',
#   'RHOC',
#   'GNG8'],
#  'REACTOME_SIGNALING_BY_ILS': ['SHC1',
#   'GRB2',
#   'IRAK4',
#   'JAK2',
#   'PELI3',
#   'TAB2',
#   'NOD2',
#   'IL1R1',
#   'UBE2N',
#   'PIK3R1',
#   'IL1RAP',
#   'MAP3K7',
#   'LCK',
#   'IL2RB',
#   'RELA',
#   'PIK3R3',
#   'MAP2K4',
#   'TEC',
#   'YWHAB'],
#  'REACTOME_SIGNALING_BY_INSULIN_RECEPTOR': ['GRB2',
#   'PRKAB1',
#   'ATP6V0E1',
#   'IRS1',
#   'PDPK1',
#   'HRAS',
#   'YWHAB',
#   'ATP6V1D',
#   'PRKAG2',
#   'IRS2',
#   'CRK',
#   'MTOR',
#   'ATP6V1E2',
#   'PPM1A',
#   'MLST8'],
#  'REACTOME_SIGNALING_BY_NOTCH': ['ATP2A2',
#   'HDAC10',
#   'ARRB2',
#   'HDAC6',
#   'DTX1',
#   'JAG1',
#   'RFNG',
#   'HDAC11',
#   'POFUT1',
#   'APH1A',
#   'MYC',
#   'ADAM17',
#   'DTX4',
#   'HEY1',
#   'LFNG',
#   'HIF1A',
#   'APH1B'],
#  'REACTOME_SIGNALING_BY_NOTCH1': ['MAMLD1',
#   'CCNC',
#   'JAG1',
#   'RBPJ',
#   'HDAC10',
#   'HES1',
#   'DTX2',
#   'HDAC1',
#   'MYC',
#   'PSENEN',
#   'DTX4',
#   'TLE3'],
#  'REACTOME_SIGNALING_BY_PDGF': ['ADCY4',
#   'FOXO4',
#   'PRKCA',
#   'PHLPP1',
#   'PIK3CB',
#   'AKT1',
#   'PDGFA',
#   'STAT3',
#   'MAPKAP1',
#   'NCK1',
#   'AKT3',
#   'PDGFRB',
#   'SPP1',
#   'AKT1S1',
#   'MAPK3',
#   'THEM4',
#   'ADCY3',
#   'MAP2K2',
#   'STAT5B'],
#  'REACTOME_SIGNALING_BY_RHO_GTPASES': ['GMIP',
#   'NET1',
#   'ARHGAP11A',
#   'ARHGAP22',
#   'VAV3',
#   'RAC1',
#   'ARHGAP19',
#   'STARD8',
#   'VAV1',
#   'A2M',
#   'BCR',
#   'PLEKHG2',
#   'FGD2',
#   'ARHGEF9',
#   'ARHGAP6',
#   'ARHGEF18',
#   'TAGAP'],
#  'REACTOME_SIGNALING_BY_SCF_KIT': ['GSK3A',
#   'TSC2',
#   'MAP2K1',
#   'THEM4',
#   'MAPK3',
#   'YES1',
#   'GRAP2',
#   'SOCS1',
#   'PDPK1',
#   'PRKCA',
#   'HRAS',
#   'CBL',
#   'FES',
#   'CHEK1'],
#  'REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEX': ['PPP1R15A',
#   'CCNC',
#   'CDKN2B',
#   'STUB1',
#   'PPP1CA',
#   'HDAC1',
#   'CCNT1',
#   'ZFYVE9',
#   'RPS27A',
#   'PARD6A',
#   'SMAD2'],
#  'REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR': ['PSMD11',
#   'VAV1',
#   'PSMA2',
#   'SKP1',
#   'NRAS',
#   'CBL',
#   'AKT3',
#   'PSME1',
#   'PSMD7',
#   'PSMB7',
#   'PSMB4',
#   'THEM4',
#   'SHC1',
#   'CALM2',
#   'PSMB5',
#   'PSMC5',
#   'CD79B',
#   'PRKCB',
#   'PSMB1',
#   'PIK3R1',
#   'PIK3CD',
#   'PSMB8',
#   'CUL1'],
#  'REACTOME_SIGNALING_BY_WNT': ['PSMC5',
#   'PSMD11',
#   'PPP2R5C',
#   'FRAT1',
#   'UBA52',
#   'PSMD1',
#   'PSMD6',
#   'PPP2R5D',
#   'PSMF1',
#   'PSMB9',
#   'PPP2R1A',
#   'PSMB5'],
#  'REACTOME_SIGNALLING_BY_NGF': ['MAPK8',
#   'APH1B',
#   'CLTA',
#   'PDE1B',
#   'NRAS',
#   'ADCY6',
#   'IRS2',
#   'MDM2',
#   'ITGB3BP',
#   'SOS1',
#   'ADCY4',
#   'RPS6KA3',
#   'PRKCI',
#   'DNAL4',
#   'PSEN2',
#   'CAMK4',
#   'DUSP3',
#   'RAF1',
#   'GSK3A',
#   'PLCG1',
#   'PPP2R5D',
#   'TRIO',
#   'BRAF',
#   'SMPD2',
#   'KALRN',
#   'RASGRF2',
#   'DUSP4',
#   'AKT1S1',
#   'ADAM17',
#   'CHUK',
#   'FGD3',
#   'IRS1',
#   'CDKN1B',
#   'RALB',
#   'TSC2',
#   'PPP2CB',
#   'AP2A1'],
#  'REACTOME_SIGNALLING_TO_ERKS': ['RAP1A',
#   'MAPK3',
#   'SRC',
#   'KRAS',
#   'MAPK14',
#   'SHC1'],
#  'REACTOME_SIGNAL_TRANSDUCTION_BY_L1': ['ITGA9',
#   'MAPK1',
#   'AP2A2',
#   'CSNK2A1',
#   'AP2A1',
#   'FGFR1'],
#  'REACTOME_SLC_MEDIATED_TRANSMEMBRANE_TRANSPORT': ['NUP210',
#   'SLC8A3',
#   'SLC44A1',
#   'SLC39A1',
#   'NUP50',
#   'SLC35D1',
#   'SLC9A5',
#   'SLC1A4',
#   'SLC2A9',
#   'SLC24A3',
#   'SLC9A7',
#   'SLC12A6',
#   'SLC14A1',
#   'SLC41A2',
#   'SLC39A10',
#   'SLC12A4',
#   'RHAG',
#   'SLC22A4',
#   'SLC22A1',
#   'SLC15A4',
#   'SLC35B2',
#   'G6PC3',
#   'NUP43',
#   'NUP214',
#   'SLC26A2',
#   'SLCO3A1',
#   'SLC39A6',
#   'SEH1L'],
#  'REACTOME_SPHINGOLIPID_METABOLISM': ['SPTLC1',
#   'HEXB',
#   'SGPP1',
#   'ACER3',
#   'VAPB',
#   'ARSG',
#   'SUMF2',
#   'KDSR',
#   'PPAP2A'],
#  'REACTOME_SRP_DEPENDENT_COTRANSLATIONAL_PROTEIN_TARGETING_TO_MEMBRANE': ['RPL35A',
#   'RPS18',
#   'SRP68',
#   'RPS25',
#   'RPS13',
#   'RPL27',
#   'RPL23',
#   'RPN1',
#   'RPL10',
#   'SEC61B',
#   'RPS7',
#   'RPS27A',
#   'SEC61G',
#   'SRP72',
#   'RPS2',
#   'RPS9',
#   'SPCS1',
#   'RPL11',
#   'SEC61A1',
#   'UBA52'],
#  'REACTOME_SYNTHESIS_OF_DNA': ['MCM2',
#   'PSMD3',
#   'PSMA3',
#   'POLA1',
#   'PSMB9',
#   'MCM6',
#   'RPA2',
#   'GINS4',
#   'PSMD12',
#   'PSME4',
#   'PSMC6',
#   'PSMD14',
#   'PSMC3',
#   'PSMD4',
#   'RFC2',
#   'MCM8',
#   'POLE2'],
#  'REACTOME_S_PHASE': ['PSMD11',
#   'POLD3',
#   'PSMD7',
#   'MCM2',
#   'POLD1',
#   'MCM8',
#   'LIG1',
#   'MCM4',
#   'PSMA5',
#   'PSMB1',
#   'RFC5',
#   'MAX',
#   'RFC3',
#   'PRIM2',
#   'RFC2',
#   'GINS1',
#   'PSMB6',
#   'PSMB8',
#   'WEE1',
#   'PSMD1'],
#  'REACTOME_TCA_CYCLE_AND_RESPIRATORY_ELECTRON_TRANSPORT': ['MDH2',
#   'UCP3',
#   'NDUFA8',
#   'UQCRQ',
#   'NDUFB3',
#   'NDUFC1',
#   'ATP5G1',
#   'PDP2',
#   'NDUFA9',
#   'ATP5C1',
#   'ETFA',
#   'PDK2',
#   'SDHA',
#   'NDUFB1',
#   'SLC16A3',
#   'NDUFV2',
#   'NDUFA12',
#   'NDUFA1',
#   'PDHX',
#   'UQCRH',
#   'NDUFB5',
#   'BSG'],
#  'REACTOME_TCR_SIGNALING': ['CD247',
#   'LCK',
#   'PRKCQ',
#   'CD3G',
#   'RELA',
#   'RIPK2',
#   'HLA-DPB1',
#   'CD3D',
#   'PTPRC'],
#  'REACTOME_TELOMERE_MAINTENANCE': ['POT1',
#   'POLE',
#   'TERF1',
#   'RPA2',
#   'RPA1',
#   'HIST2H2BE',
#   'POLD1',
#   'DNA2'],
#  'REACTOME_TOLL_RECEPTOR_CASCADES': ['DNM2',
#   'TAB1',
#   'PELI3',
#   'TRAF3',
#   'CREB1',
#   'EEA1',
#   'TLR7',
#   'DUSP7',
#   'ATF2',
#   'MAP2K7',
#   'MAP2K1',
#   'MAPKAPK2',
#   'SIGIRR',
#   'ELK1',
#   'NOD1',
#   'RPS6KA5',
#   'TAB3',
#   'MYD88',
#   'CD180',
#   'LY96',
#   'S100B'],
#  'REACTOME_TRAF6_MEDIATED_INDUCTION_OF_NFKB_AND_MAP_KINASES_UPON_TLR7_8_OR_9_ACTIVATION': ['MAP3K7',
#   'ECSIT',
#   'MAPK1',
#   'RPS6KA3',
#   'MAPK9',
#   'MAPK14',
#   'DUSP7',
#   'CHUK',
#   'HMGB1',
#   'RPS6KA5',
#   'PPP2CB',
#   'TAB1',
#   'PELI1',
#   'NOD1'],
#  'REACTOME_TRANSCRIPTION': ['H3F3B',
#   'KAT2B',
#   'TCEB3',
#   'GTF2E1',
#   'TAF4',
#   'RRN3',
#   'POLR3B',
#   'RNGTT',
#   'TAF4B',
#   'TAF6',
#   'H3F3A',
#   'TAF5',
#   'RNMT',
#   'ERCC2',
#   'NFX1',
#   'GTF3C4',
#   'H2AFX',
#   'POLR1C',
#   'NCBP2',
#   'GTF2E2',
#   'MAGOH',
#   'SNAPC3',
#   'GTF3C2',
#   'UBTF',
#   'POLR2H',
#   'CCNT2',
#   'GTF2H1',
#   'SUPT16H',
#   'GTF2H2'],
#  'REACTOME_TRANSCRIPTIONAL_ACTIVITY_OF_SMAD2_SMAD3_SMAD4_HETEROTRIMER': ['CDKN2B',
#   'MEN1',
#   'PPM1A',
#   'RPS27A',
#   'CDK8',
#   'UBA52',
#   'SKIL'],
#  'REACTOME_TRANSCRIPTIONAL_REGULATION_OF_WHITE_ADIPOCYTE_DIFFERENTIATION': ['CDK8',
#   'CDK4',
#   'SMARCD3',
#   'WNT1',
#   'MED24',
#   'KLF5',
#   'PPARA',
#   'MED1',
#   'MED4',
#   'TBL1XR1',
#   'TGFB1',
#   'MED29'],
#  'REACTOME_TRANSCRIPTION_COUPLED_NER_TC_NER': ['GTF2H1',
#   'POLE',
#   'RPA1',
#   'POLD3',
#   'PCNA',
#   'POLR2E',
#   'ERCC5',
#   'POLR2A'],
#  'REACTOME_TRANSLATION': ['RPL28',
#   'RPL23A',
#   'EEF1D',
#   'EIF3K',
#   'RPSA',
#   'RPL31',
#   'RPL10A',
#   'RPL12',
#   'RPS3',
#   'RPL26',
#   'RPL22',
#   'EEF2',
#   'EIF2B2',
#   'EIF4A1',
#   'RPLP0',
#   'RPL13A',
#   'RPS27A',
#   'RPL15',
#   'EIF4EBP1',
#   'RPL14',
#   'EIF2S2',
#   'SSR1',
#   'EIF2B3',
#   'EIF4H',
#   'EIF3A',
#   'SSR3',
#   'RPS24'],
#  'REACTOME_TRANSMEMBRANE_TRANSPORT_OF_SMALL_MOLECULES': ['GNG8',
#   'SLC38A1',
#   'SLC4A2',
#   'SLC3A2',
#   'SLC33A1',
#   'SLC7A8',
#   'ATP2A1',
#   'SLC35D1',
#   'ABCB10',
#   'MCOLN1',
#   'ATP1B3',
#   'RAB11A',
#   'ABCA2',
#   'SLC2A8',
#   'ATP11B',
#   'TPR',
#   'SLC22A16',
#   'ATP8A2',
#   'SLC35C1',
#   'SLC35A2',
#   'ATP6V1G2',
#   'SLC6A9',
#   'ABCC3',
#   'SLC35D2',
#   'NUP85',
#   'SLC15A4',
#   'ATP6V1E2',
#   'GNB2',
#   'ATP9B',
#   'NUP50',
#   'SLC35A1',
#   'SLC12A2',
#   'ATP6V1E1',
#   'AAAS',
#   'ADCY9',
#   'ATP8B3',
#   'RANBP2',
#   'ATP2A3',
#   'SLC38A2',
#   'SLC24A3',
#   'RHAG',
#   'SLC41A1',
#   'ATP7B',
#   'ATP6V1D',
#   'SLC39A3',
#   'SLC15A2',
#   'SLC7A5',
#   'RAB11FIP2'],
#  'REACTOME_TRANSMISSION_ACROSS_CHEMICAL_SYNAPSES': ['AP2A2',
#   'CAMK2D',
#   'SLC1A7',
#   'MDM2',
#   'UNC13B',
#   'AP2M1',
#   'CACNB1',
#   'GNG5',
#   'KCNJ2',
#   'GNAI3',
#   'HSPA8',
#   'RAF1',
#   'CACNB2',
#   'GNG8',
#   'ADCY7',
#   'SLC6A12',
#   'SLC38A2',
#   'GNG11'],
#  'REACTOME_TRANSPORT_OF_GLUCOSE_AND_OTHER_SUGARS_BILE_SALTS_AND_ORGANIC_ACIDS_METAL_IONS_AND_AMINE_COMPOUNDS': ['SLC22A16',
#   'SLC2A5',
#   'SLC6A12',
#   'SLC39A1',
#   'SLC16A1',
#   'SLC31A1',
#   'SLC2A11',
#   'SLC22A5'],
#  'REACTOME_TRANSPORT_OF_INORGANIC_CATIONS_ANIONS_AND_AMINO_ACIDS_OLIGOPEPTIDES': ['SLC9A6',
#   'SLC15A4',
#   'SLC7A11',
#   'SLC7A5',
#   'SLC6A6',
#   'SLC43A1',
#   'SLC4A1',
#   'SLC4A7',
#   'SLC1A7',
#   'SLC26A6'],
#  'REACTOME_TRANSPORT_OF_MATURE_MRNA_DERIVED_FROM_AN_INTRONLESS_TRANSCRIPT': ['NUP107',
#   'NUP205',
#   'TPR',
#   'CPSF2',
#   'NUP155',
#   'NUP54'],
#  'REACTOME_TRANSPORT_OF_MATURE_TRANSCRIPT_TO_CYTOPLASM': ['SRSF5',
#   'SRSF3',
#   'U2AF2',
#   'NUP153',
#   'SRSF11',
#   'NUP107',
#   'SLBP',
#   'NUPL2',
#   'SEH1L',
#   'SRSF2'],
#  'REACTOME_TRANSPORT_TO_THE_GOLGI_AND_SUBSEQUENT_MODIFICATION': ['LMAN1',
#   'SEC24C',
#   'SEC23A',
#   'B4GALT5',
#   'B4GALT4'],
#  'REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDING': ['NAPA',
#   'AP3B1',
#   'AP1G1',
#   'TBC1D8B',
#   'YIPF6',
#   'ARF1',
#   'AP1B1',
#   'SNX2',
#   'BLOC1S3',
#   'CLTC'],
#  'REACTOME_TRIF_MEDIATED_TLR3_SIGNALING': ['RPS6KA3',
#   'DUSP7',
#   'MAPK14',
#   'PPP2R5D',
#   'ATF2',
#   'HMGB1',
#   'S100B',
#   'RIPK2',
#   'CDK1',
#   'ELK1',
#   'MAP2K6',
#   'NFKBIB',
#   'MEF2C',
#   'RIPK3'],
#  'REACTOME_TRIGLYCERIDE_BIOSYNTHESIS': ['ELOVL6',
#   'HSD17B12',
#   'LPIN1',
#   'SLC25A1',
#   'ELOVL7',
#   'AGPAT3'],
#  'REACTOME_TRNA_AMINOACYLATION': ['FARS2',
#   'PPA1',
#   'HARS',
#   'DARS',
#   'IARS',
#   'YARS2',
#   'HARS2',
#   'PARS2'],
#  'REACTOME_UNFOLDED_PROTEIN_RESPONSE': ['GOSR2',
#   'FKBP14',
#   'SHC1',
#   'CUL7',
#   'C19orf10',
#   'EDEM1',
#   'HERPUD1',
#   'EXOSC4',
#   'LMNA',
#   'ATP6V0D1',
#   'EXOSC1',
#   'EIF2S1',
#   'NFYA',
#   'EXOSC9'],
#  'REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G': ['PSMD7',
#   'PSMB6',
#   'PSMB1',
#   'RBX1',
#   'PSMA1',
#   'RPS27A',
#   'PSMB5',
#   'PSMD9',
#   'PSME4'],
#  'SIG_BCR_SIGNALING_PATHWAY': ['SHC1',
#   'PIK3R1',
#   'INPP5D',
#   'VAV1',
#   'ITPR3',
#   'BCR',
#   'MAPK1',
#   'PIK3CA',
#   'AKT1'],
#  'SIG_CD40PATHWAYMAP': ['MAP2K7',
#   'MAPK8IP3',
#   'MAPK8IP2',
#   'IKBKG',
#   'MAPKAPK5',
#   'MAP2K4'],
#  'SIG_CHEMOTAXIS': ['PIK3CG',
#   'INPPL1',
#   'LIMK1',
#   'GDI1',
#   'AKT3',
#   'WASL',
#   'GDI2'],
#  'SIG_INSULIN_RECEPTOR_PATHWAY_IN_CARDIAC_MYOCYTES': ['SORBS1',
#   'YWHAH',
#   'CBL',
#   'SHC1',
#   'FLOT2',
#   'RAF1',
#   'AKT3',
#   'CAP1'],
#  'SIG_PIP3_SIGNALING_IN_B_LYMPHOCYTES': ['RPS6KA3',
#   'PPP1R13B',
#   'GAB1',
#   'ITPR1',
#   'FLOT2',
#   'RPS6KA2'],
#  'SIG_PIP3_SIGNALING_IN_CARDIAC_MYOCTES': ['YWHAG',
#   'TSC1',
#   'BAD',
#   'GSK3A',
#   'PPP1R13B',
#   'PAK6',
#   'TSC2',
#   'NOLC1',
#   'PIK3CA',
#   'AKT1',
#   'PTK2'],
#  'ST_B_CELL_ANTIGEN_RECEPTOR': ['DAG1',
#   'GRB2',
#   'PIK3CD',
#   'MAPK1',
#   'BAD',
#   'AKT3',
#   'CD19'],
#  'ST_DIFFERENTIATION_PATHWAY_IN_PC12_CELLS': ['MAPK3',
#   'CAMP',
#   'ELK1',
#   'MAP2K4',
#   'SRC',
#   'AKT1',
#   'RASGRF2'],
#  'ST_ERK1_ERK2_MAPK_PATHWAY': ['MAP2K1',
#   'CREB5',
#   'SOS2',
#   'GRB2',
#   'KLF6',
#   'RPS6KA3'],
#  'ST_FAS_SIGNALING_PATHWAY': ['FAS',
#   'DEDD2',
#   'CASP8AP2',
#   'NFKBIL1',
#   'MAP3K5',
#   'CSNK1A1',
#   'MAP3K1',
#   'CAD',
#   'BFAR',
#   'MAP2K7',
#   'EPHB2'],
#  'ST_GA13_PATHWAY': ['RDX', 'MAPK8', 'AKT1', 'PLD3', 'PHKA2', 'NFKBIB'],
#  'ST_INTEGRIN_SIGNALING_PATHWAY': ['RAF1',
#   'PIK3CB',
#   'PTK2',
#   'MAPK8',
#   'ASAP1',
#   'FYN',
#   'CRK',
#   'ITGA4',
#   'AKT2',
#   'ROCK2',
#   'TERF2IP',
#   'CSE1L',
#   'ITGA7'],
#  'ST_JNK_MAPK_PATHWAY': ['MAP3K7',
#   'MYEF2',
#   'MAP3K3',
#   'DUSP8',
#   'TRAF6',
#   'MAP2K4',
#   'MAP3K10'],
#  'ST_P38_MAPK_PATHWAY': ['TRAF6',
#   'DUSP10',
#   'MAP2K3',
#   'ATF1',
#   'MAP3K10',
#   'MAPK14',
#   'CREB1'],
#  'ST_PHOSPHOINOSITIDE_3_KINASE_PATHWAY': ['INPP5D',
#   'SHC1',
#   'IARS',
#   'CD55',
#   'YWHAG',
#   'PPP1R13B'],
#  'ST_T_CELL_SIGNAL_TRANSDUCTION': ['NFAT5',
#   'GRB2',
#   'FBXW7',
#   'PTPRC',
#   'NCK1',
#   'SOS1',
#   'MAPK1',
#   'ZAP70'],
#  'SVM B cells memory': ['IL7',
#   'GNG7',
#   'SLC12A1',
#   'FAIM',
#   'GPR18',
#   'CD19',
#   'FCGR2B',
#   'SP1',
#   'BACH2',
#   'CR2'],
#  'SVM B cells naive': ['BEND5',
#   'ZNF28',
#   'P2RX5',
#   'IL4R',
#   'FCGR2B',
#   'ADAM28',
#   'LY86',
#   'TCL1A',
#   'CD79B',
#   'RASGRP2'],
#  'SVM Dendritic cells activated': ['CCL5',
#   'LAMP3',
#   'CLIC2',
#   'IL2RA',
#   'ETV3',
#   'SLC15A3'],
#  'SVM Dendritic cells resting': ['PPFIBP1',
#   'PLA2G7',
#   'FZD2',
#   'IGSF6',
#   'CD209',
#   'FAM198B'],
#  'SVM Eosinophils': ['FFAR2',
#   'RNASE2',
#   'EMR2',
#   'SMPD3',
#   'REPS2',
#   'P2RY10',
#   'RRP12',
#   'DEPDC5',
#   'EMR1'],
#  'SVM Macrophages M0': ['IGSF6', 'NCF2', 'CHI3L1', 'CYP27A1'],
#  'SVM Macrophages M1': ['SLAMF1', 'ARRB1', 'RSAD2', 'SLC2A6', 'PTGIR', 'NOD2'],
#  'SVM Macrophages M2': ['TLR8', 'RENBP', 'CD4', 'NPL'],
#  'SVM Mast cells activated': ['HDC', 'MS4A3', 'FCER1A', 'MARCH3'],
#  'SVM Mast cells resting': ['MS4A3', 'C3', 'SEPT8', 'BMP2K', 'GFI1'],
#  'SVM Monocytes': ['LILRB2',
#   'CFP',
#   'MEFV',
#   'CD1D',
#   'APOBEC3A',
#   'CLEC7A',
#   'FAM198B',
#   'FOSB',
#   'C5AR1',
#   'VNN2'],
#  'SVM NK cells activated': ['GRAP',
#   'TNFSF14',
#   'FASLG',
#   'FAS',
#   'CST7',
#   'CCL5',
#   'SH2D1A',
#   'TXK',
#   'CD69',
#   'GNLY',
#   'PRR5'],
#  'SVM NK cells resting': ['CD160',
#   'CEACAM8',
#   'PTPRC',
#   'KLRF1',
#   'ZNF135',
#   'ZAP70',
#   'TXK',
#   'GZMM',
#   'CD9',
#   'GFI1'],
#  'SVM Neutrophils': ['CFP',
#   'CAMP',
#   'P2RY14',
#   'TREML2',
#   'GPR97',
#   'TNFRSF10C',
#   'CASP5',
#   'FPR2',
#   'VNN2',
#   'EMR3',
#   'TLR8'],
#  'SVM Plasma cells': ['CD27', 'RPL3', 'MANEA', 'RASGRP3', 'SIK1'],
#  'SVM T cells CD4 memory activated': ['CD28', 'CD2', 'CD3D', 'GPR171', 'CD3G'],
#  'SVM T cells CD4 memory resting': ['RASGRP2',
#   'CD3G',
#   'LTB',
#   'IL7R',
#   'CD69',
#   'RCAN3',
#   'SH2D1A',
#   'TRAT1',
#   'UBASH3A',
#   'GRAP2',
#   'ICOS'],
#  'SVM T cells CD4 naive': ['CCR7',
#   'MAP4K2',
#   'CXorf57',
#   'UBASH3A',
#   'LY9',
#   'ZAP70',
#   'ICOS',
#   'GRAP2',
#   'CD7'],
#  'SVM T cells CD8': ['KLRF1',
#   'CD3D',
#   'TCF7',
#   'GZMH',
#   'KLRK1',
#   'ZAP70',
#   'FAIM3',
#   'CCL5',
#   'ITK',
#   'FLT3LG',
#   'CD247',
#   'KLRD1'],
#  'SVM T cells follicular helper': ['CD27',
#   'TRIB2',
#   'ICA1',
#   'ITK',
#   'SLC7A1',
#   'ICOS',
#   'CD69',
#   'SIK1',
#   'CXCR5',
#   'BCL11B'],
#  'SVM T cells gamma delta': ['KRT18',
#   'KLRG1',
#   'IL18RAP',
#   'GZMM',
#   'CD247',
#   'TCF7',
#   'CD3D',
#   'KLRK1',
#   'GFI1',
#   'GPR18'],
#  'SVM T cells regulatory (Tregs)': ['TRAT1',
#   'LILRA4',
#   'SIT1',
#   'ZAP70',
#   'CD3G',
#   'CD4',
#   'BCL11B',
#   'CD3D',
#   'CD3E'],
#  'WNT_SIGNALING': ['SENP2',
#   'LRP5',
#   'FZD3',
#   'RPL13A',
#   'CTBP1',
#   'JUN',
#   'BTRC',
#   'FBXW4',
#   'CTNNB1',
#   'FOSL1',
#   'NKD1',
#   'RHOU']}

# %%
plierRes = {
    "B": plierRes_b,
    "C": plierRes_c,
    "U": plierRes_u,
    "Z": plierRes_z,
    "residual": plierRes_residual,
    "heldOutGenes": heldOutGenes,
}
